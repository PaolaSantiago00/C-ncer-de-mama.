# %% [markdown]
# #**Estudio del gen BRCA en cáncer de mama**
# ---
# 🔗https://github.com/PaolaSantiago00/C-ncer-de-mama-/blob/main/README.md

# %% [markdown]
# ##**Introducción**
#
#
# ---
#  El gen de BRCA1 y BRCA2 se tratan de genes de predisposición de cáncer de mama y ovario. Si bien por estructura génetica es propio del ser humano contar con dichos genes, sin embargo, debido en diversos individuos pueden presentarse mutaciones que aumenten el riesgo de desarrollar cáncer de mama.
#
# Buscando dar resolución a nuestros objetivos planteados, utilizando datos de [cBioPortal](https://www.cbioportal.org/).

# %% [markdown]
# 📚 **Referencias**
#
#
# ---
#
#
#
# 1.   Varol, et. al (2018). *BRCA genes: BRCA 1 and BRCA 2*. Recuperado de
# https://jbuon.com/archive/23-4-862.pdf

# %% [markdown]
# ##**Objetivos**

# %% [markdown]
# **Se va analizar datasets del cáncer de mama, junto con sus mutaciones BRCA1 y BRCA2**
#
# Se pretende dar respuesta a las siguientes preguntas:
#
# *  ¿En qué edad se encuentra el mayor porcentaje de casos con cáncer de mama?
# *  ¿Existen patrones geográficos en la prevalencia de cáncer de mama?
# *  ¿Cuál es la frecuencia de supervivencia entre las pacientes?
# *  ¿Cuál es el “tipo de cáncer” de mama con más casos?

# %% [markdown]
# ##**Desarrollo de proyecto**
#
#
# ---
# A partir de esta sección, se podrá encontrar el código realizado para llevar a
# cabo el análisis correspondiente

# %%
#Librerías

import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import skew, kurtosis
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate

# %% [markdown]
# ##**Cáncer de mama**

# %%
df_mama = pd.read_csv("https://raw.githubusercontent.com/PaolaSantiago00/C-ncer-de-mama/main/combined_study_clinical_data.csv")

df_mama.head()
# Out:
#                Study ID          Patient ID          Sample ID  \
# 0  brca_pareja_msk_2020  brca_impact_wes_25             25DCIS
# 1  brca_pareja_msk_2020  brca_impact_wes_25              25IDC
# 2     bfn_duke_nus_2015   BFN_DUKE_NUS_1007  BFN_DUKE_NUS_1007
# 3            brca_broad            BR-M-027           BR-M-027
# 4            brca_broad            BR-V-023           BR-V-023
#
#    Adjuvant Chemotherapy  Adjuvant Treatment  Diagnosis Age     Cancer Type  \
# 0                    NaN                 NaN            NaN   Breast Cancer
# 1                    NaN                 NaN            NaN   Breast Cancer
# 2                    NaN                 NaN           26.0  Breast Sarcoma
# 3                    NaN                 NaN           51.0   Breast Cancer
# 4                    NaN                 NaN           40.0   Breast Cancer
#
#                    Cancer Type Detailed ER Status By IHC  Followup (years)  \
# 0                                Breast              NaN               NaN
# 1                                Breast              NaN               NaN
# 2  Benign Phyllodes Tumor of the Breast              NaN               NaN
# 3         Infiltrating Ductal Carcinoma              NaN               NaN
# 4       Ductal Carcinoma In Situ (DCIS)              NaN               NaN
#
#    ...  Time To Death (Months)  Tumor Sample Histology Tumor Tissue Origin  \
# 0  ...                     NaN                     NaN                 NaN
# 1  ...                     NaN                     NaN                 NaN
# 2  ...                     NaN                     NaN                 NaN
# 3  ...                     NaN                     NaN                 NaN
# 4  ...                     NaN                     NaN                 NaN
#
#    T Stage Archer Panel Institute Source  Patient Display Name.1  \
# 0      NaN          NaN              NaN                     NaN
# 1      NaN          NaN              NaN                     NaN
# 2      NaN          NaN              NaN                     NaN
# 3      NaN          NaN              NaN                     NaN
# 4      NaN          NaN              NaN                     NaN
#
#    Sample Display Name  Tumor Site  Tumor Size (cm)
# 0                  NaN         NaN              NaN
# 1                  NaN         NaN              NaN
# 2                  NaN         NaN              NaN
# 3                  NaN         NaN              NaN
# 4                  NaN         NaN              NaN
#
# [5 rows x 397 columns]

# %%
#Investigar con cuantas filas y columnas cuenta el dataset
num_filas_np, num_columnas_np = df_mama.shape

print("Número de filas:", num_filas_np)
print("Número de columnas:", num_columnas_np)
# Out:
# Número de filas: 482
# Número de columnas: 397

# %%
# Obtener e imprimir el nombre de todas las columnas
print("Nombres de las columnas:")
for nombre_columna in df_mama.columns:
    print(nombre_columna)
# Out:
# Nombres de las columnas:
# Study ID
# Patient ID
# Sample ID
# Adjuvant Chemotherapy
# Adjuvant Treatment
# Diagnosis Age
# Cancer Type
# Cancer Type Detailed
# ER Status By IHC
# Followup (years)
# Fusion Status
# Genomic Alterations
# IHC-HER2
# Local Regional Recurrence
# Metastatic Site
# Metastatic tumor indicator
# Mutation Count
# MYB or MYBL1 Fusion
# MYB-NFIB Fusion Gene Copy Number Alterations
# MYB-NFIB FISH
# MYB-NFIB Fusion Gene Non-synonymous Mutations
# MYB-NFIB Rearrangement
# Neoadjuvant Chemotherapy
# Oncotree Code
# Overall Patient Histology
# Platform
# Primary Tumor Site
# PR status by ihc
# Radiation Therapy
# Number of Samples Per Patient
# Sample Type
# Sex
# Somatic Status
# Study
# Time to Metastasis (months)
# TMB (nonsynonymous)
# Tumor Size
# Tumor Stage
# Type of Surgery
# Patient's Vital Status
# Ethnicity Category
# Neoplasm Histologic Type Name
# Mean Coverage (x)
# Total Number of Somatic Mutations
# Surgery
# Angiolymphatic Invasion
# Neoplasm American Joint Committee on Cancer Clinical Distant Metastasis M Stage
# Neoplasm American Joint Committee on Cancer Clinical Regional Lymph Node N Stage
# ER Status
# Estimated Tumor Cellularity
# Neoplasm Histologic Grade
# Histological Type
# IHC_BASAL
# IHC_CK5/6
# IHC_EGFR
# PAM50 subtype
# PR Status
# Fraction Genome Altered
# Sample Class
# Sequencing Type
# Country
# HER2 Amplification Status
# HER2 Status
# Menopause Status
# Nonsilent Mutation Rate
# Ploidy
# Purity
# Silent Mutation Rate
# Stage
# Subtype
# APOBEC Signature
# Cancer type
# CD3 TILS Counts
# CD3 TILS Status
# Chromosome INstability index CIN
# CIBERSORT Absolute Score
# ERBB2 Gene Amplified
# ERBB2 Proteogenomic Status
# ERBB2 Updated Clinical Status
# ER Updated Clinical Status
# ESTIMATE Immune Score
# ESTIMATE Stromal Score
# ESTIMATE TumorPurity
# Ischemia Time in Minutes
# NMF Cluster
# NMF Cluster Membership Score
# Number of non synonymous Mutations
# Oncotree code
# PAM50
# PR Clinical Status
# Stemness Score
# TMT Channel
# TMT Plex
# TNBC Updated Clinical Status
# TOP2A Gene Amplified
# TOP2A Proteogenomic Status
# xCell Immune Score
# xCell Stromal Score
# Disease Status
# Overall Survival (Months)
# Overall Survival Status
# Patient Tumor Grade
# Race Category
# Sample Collection Method
# Specimen Preservation Type
# Specimen Site
# Specimen Type
# Time to Last Followup
# Study ID.1
# ER
# HER2
# Diagnosis P Stage
# Gene Panel
# Histology
# MSI Comment
# MSI Score
# MSI Type
# Progress Free Survival (Months)
# Progression Free Status
# Reason Stop
# Religion
# Sample coverage
# Sample Status
# SO comments
# Tumor Mutation Burden
# Tumor Purity
# Treatment Line
# Treatment Location
# Treatment Regimen
# Age at Diagnosis
# Type of Breast Surgery
# Cellularity
# Chemotherapy
# Pam50 + Claudin-low subtype
# Cohort
# ER status measured by IHC
# HER2 status measured by SNP6
# Tumor Other Histologic Subtype
# Hormone Therapy
# Inferred Menopausal State
# Integrative Cluster
# Primary Tumor Laterality
# Lymph nodes examined positive
# Nottingham prognostic index
# Radio Therapy
# Relapse Free Status (Months)
# Relapse Free Status
# 3-Gene classifier subtype
# Best Response to Therapy
# block accession
# Comments
# months on study
# Months on Treatment
# Other Patient ID
# patient study id
# PIK3CA Mutation
# reason for tx discontinuation
# Sample origin
# snapshot mutations
# Status
# study arm
# therapy
# Treatment best response
# Aberrant Cell Fraction
# Histopathology
# Mitotic Count
# Mitotic Score
# Pleomorphism Score
# Tubule Score
# Tumor Ploidy
# Center of sequencing
# Cytolytic Activity Score
# Histology
# Immunohistochemistry Subtype
# TNM Stage
# Menopausal Status At Diagnosis
# Mutation Burden
# Subtype Consensus
# Chemotherapy.1
# American Joint Committee on Cancer Metastasis Stage Code
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code
# Neoplasm Disease Stage American Joint Committee on Cancer Code
# American Joint Committee on Cancer Publication Version Type
# American Joint Committee on Cancer Tumor Stage Code
# Brachytherapy first reference point administered total dose
# Cent17 Copy Number
# Neoplasm American Joint Committee on Cancer Clinical Group Stage
# Neoplasm American Joint Committee on Cancer Clinical Primary Tumor T Stage
# Days to Sample Collection.
# Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value
# days_to_patient_progression_free
# Days to Sample Procurement
# days_to_tumor_progression
# Disease Free (Months)
# Disease Free Status
# Disease code
# ER positivity scale other
# ER positivity scale used
# ER Status IHC Percent Positive
# Lymphomatous Extranodal Site Involvement Indicator
# First surgical procedure other
# Form completion date
# HER2 and cent17 cells count
# HER2 and cent17 scale other
# HER2 cent17 counted cells count
# HER2 cent17 ratio
# HER2 copy number
# HER2 fish method
# HER2 fish status
# HER2 ihc percent positive
# HER2 ihc score
# HER2 positivity method text
# HER2 positivity scale other
# Neoadjuvant Therapy Type Administered Prior To Resection Text
# Prior Cancer Diagnosis Occurence
# ICD-10 Classification
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code
# IHC Score
# Informed consent verified
# Year Cancer Initial Diagnosis
# Is FFPE
# Longest Dimension
# Primary Lymph Node Presentation Assessment Ind-3
# Positive Finding Lymph Node Hematoxylin and Eosin Staining Microscopy Count
# Positive Finding Lymph Node Keratin Immunohistochemistry Staining Method Count
# Lymph Node(s) Examined Number
# Margin status reexcision
# Metastatic Site Other
# Patient Metastatic Sites
# First Pathologic Diagnosis Biospecimen Acquisition Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Other Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Method Type.1
# Micromet detection by ihc
# New Neoplasm Event Post Initial Therapy Indicator
# Nte cent17 HER2 other scale
# Nte cent 17 HER2 ratio
# Nte cent 17 signal number
# Nte er ihc intensity score
# Nte er positivity define method
# Nte er positivity other scale
# Nte er status
# Nte er status ihc positive
# Nte HER2 fish define method
# Nte HER2 fish status
# Nte HER2 positivity ihc score
# Nte HER2 positivity method
# Nte HER2 positivity other scale
# Nte HER2 signal number
# Nte HER2 status
# Nte HER2 status ihc positive
# Nte pr ihc intensity score
# Nte pr positivity define method
# Nte pr positivity other scale
# Nte pr status by ihc
# Nte pr status ihc positive
# Oct embedded
# Specimen Collection Method
# Other Sample ID
# Pathology Report File Name
# Pathology report uuid
# Disease Surgical Margin Status
# Adjuvant Postoperative Pharmaceutical Therapy Administered Indicator
# Primary Other Site of Disease Name
# Patient Primary Tumor Site
# Project code
# Tissue Prospective Collection Indicator
# PR positivity define method
# PR positivity ihc intensity score
# PR positivity scale other
# PR positivity scale used
# PR status ihc percent positive
# Did patient start adjuvant postoperative radiotherapy?
# Tissue Retrospective Collection Indicator
# Sample Initial Weight
# Sample type id
# Shortest Dimension
# Tumor Tissue Site
# Specimen Current Weight
# Specimen Freezing Means
# Specimen Second Longest Dimension
# Stage Other
# Staging System
# Staging System.1
# Surgery for positive margins
# Surgery for positive margins other
# Surgical procedure first
# Time between clamping and freezing
# Time between excision and freezing
# Tissue Source Site
# Person Neoplasm Status
# Vial number
# Aneuploidy Score
# Buffa Hypoxia Score
# TCGA PanCanAtlas Cancer Type Acronym
# Last Communication Contact from Initial Pathologic Diagnosis Date
# Birth from Initial Pathologic Diagnosis Date
# Months of disease-specific survival
# Disease-specific Survival status
# Genetic Ancestry Label
# In PanCan Pathway Analysis
# MSI MANTIS Score
# MSIsensor Score
# American Joint Committee on Cancer Metastasis Stage Code.1
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code.1
# American Joint Committee on Cancer Tumor Stage Code.1
# Person Neoplasm Cancer Status
# Primary Lymph Node Presentation Assessment
# Prior Diagnosis
# Ragnum Hypoxia Score
# Tissue Prospective Collection Indicator.1
# Tissue Retrospective Collection Indicator.1
# Tissue Source Site Code
# Tumor Disease Anatomic Site
# Tumor Type
# Patient Weight
# Winter Hypoxia Score
# CN Cluster
# Converted Stage
# Integrated Clusters (no exp)
# Integrated Clusters (unsup exp)
# Integrated Clusters (with PAM50)
# Metastasis
# Metastasis-Coded
# Methylation Cluster
# MIRNA Cluster
# Node
# Node-Coded
# RPPA Cluster
# SigClust Intrinsic mRNA
# SigClust Unsupervised mRNA
# Survival Data Form
# Tumor--T1 Coded
# Death from Initial Pathologic Diagnosis Date
# Days to Last Followup
# Nte er status ihc positive.1
# Nte HER2 status ihc positive.1
# Nte pr status ihc positive.1
# Alpelisib Dose (mg)
# Alpelisib Scheduling
# Breast Cancer Subtype
# Clinical Benefit
# Endocrine Therapy
# Measurable Disease
# Off Study Reason
# Patient Display Name
# PIK3CA Pre Treatment Tumor Mutation
# PIK3CA Pre Treatment Tumor
# Best RECIST Response
# Sample Collection Time
# Tumor Sequencing Platform
# Treatment Arm
# Weeks on Study
# Age at Which Sequencing was Reported (Years)
# Patient Current Age
# Disease Free Event
# ER PCT Primary
# ER Status of the Primary
# HER2 FISH Status of Sequenced Sample
# HER2 FISH Ratio Value of Sequenced Sample
# HER2 FISH Ratio Primary
# HER2 IHC Status Primary
# HER2 IHC Status of Sequenced Sample
# HER2 IHC Score Primary
# HER2 Primary Status
# Overall HR Status of Sequenced Sample
# Invasive Carcinoma Diagnosis Age
# Time to Diagnosis Invasive Carcinoma
# Last Communication Contact
# Metastatic Disease at Last Follow-up
# Metastatic Recurrence Time
# M Stage
# NGS Sample Collection Time Period
# N Stage
# Overall HER2 Status of Sequenced Sample
# Overall Patient HER2 Status
# Overall Patient HR Status
# Overall Patient Receptor Status
# Overall Primary Tumor Grade
# Primary Nuclear Grade
# Prior Breast Primary
# Prior Local Recurrence
# PR PCT Primary
# PR Status of the Primary
# Receptor Status Primary
# Site of Sample
# Stage At Diagnosis
# Time To Death (Months)
# Tumor Sample Histology
# Tumor Tissue Origin
# T Stage
# Archer Panel
# Institute Source
# Patient Display Name.1
# Sample Display Name
# Tumor Site
# Tumor Size (cm)

# %% [markdown]
# **Mutación** mama BRCA1

# %%
brca1_mama_mutation = pd.read_csv('https://raw.githubusercontent.com/PaolaSantiago00/C-ncer-de-mama/main/BRCA1_mama%20(separado)%20NUEVO%20-%20BRCA1_mama%20(separado)%20NUEVO.csv',index_col=0)

brca1_mama_mutation.head()
# Out:
#                                                                                  Sample ID  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                                    MBC_47
# The Metastatic Breast Cancer Project (Archived,...  MBC-MBCProject_zatdFvhp-Tumor-SM-GQAAR
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-BH-A0WA-01
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-AN-A0XU-01
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-AR-A0U4-01
#
#                                                       Cancer Type  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)    Breast Cancer
# The Metastatic Breast Cancer Project (Archived,...  Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
#
#                                                            Cancer Type Detailed  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)      Invasive Breast Carcinoma
# The Metastatic Breast Cancer Project (Archived,...  Breast Invasive Cancer, NOS
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
#
#                                                    Protein Change  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)       M1728Kfs*3
# The Metastatic Breast Cancer Project (Archived,...   X1823_splice
# Breast Invasive Carcinoma (TCGA, Nature 2012)        X1559_splice
# Breast Invasive Carcinoma (TCGA, Nature 2012)              G1788V
# Breast Invasive Carcinoma (TCGA, Nature 2012)         N1121Kfs*12
#
#                                                    Annotation OncoKb  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)    Likely Oncogenic
# The Metastatic Breast Cancer Project (Archived,...  Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
#
#                                                    CancerHotspot  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)              no
# The Metastatic Breast Cancer Project (Archived,...            no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
#
#                                                    MutationAssesor Impact  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      medium
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                     SIFT Impact  sift_score  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)            NaN         NaN
# The Metastatic Breast Cancer Project (Archived,...          NaN         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)               NaN         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)       deleterious         0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)               NaN         NaN
#
#                                                    Polyphen-2 Impact  ...  \
# Study of Origin                                                       ...
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                 NaN  ...
# The Metastatic Breast Cancer Project (Archived,...               NaN  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 benign  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN  ...
#
#                                                     Time To Death (Months)  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                       NaN
# The Metastatic Breast Cancer Project (Archived,...                     NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
#
#                                                    Tumor Sample Histology  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                     Tumor Tissue Origin  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                    NaN
# The Metastatic Breast Cancer Project (Archived,...                  NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
#
#                                                    T Stage  Archer Panel  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)       NaN           NaN
# The Metastatic Breast Cancer Project (Archived,...     NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
#
#                                                    Institute Source  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                NaN
# The Metastatic Breast Cancer Project (Archived,...              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
#
#                                                    Patient Display Name.1  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                    Sample Display Name  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                   NaN
# The Metastatic Breast Cancer Project (Archived,...                 NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
#
#                                                     Tumor Site  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)           NaN
# The Metastatic Breast Cancer Project (Archived,...         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
#
#                                                     Tumor Size (cm)
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                NaN
# The Metastatic Breast Cancer Project (Archived,...              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
#
# [5 rows x 586 columns]

# %%
#Investigamos con cuantas filas y columnas cuenta el dataset
num_filas_np, num_columnas_np = brca1_mama_mutation.shape

print("Número de filas:", num_filas_np)
print("Número de columnas:", num_columnas_np)
# Out:
# Número de filas: 225
# Número de columnas: 586

# %%
# Obtener e imprimir el nombre de todas las columnas
print("Nombres de las columnas:")
for nombre_columna in brca1_mama_mutation.columns:
    print(nombre_columna)
# Out:
# Nombres de las columnas:
# Sample ID
# Cancer Type
# Cancer Type Detailed
# Protein Change
# Annotation OncoKb
# CancerHotspot
# MutationAssesor Impact
# SIFT Impact
# sift_score
# Polyphen-2 Impact
# polyphen_2_score
# Mutation Type
# Unnamed: 13
# Copy #
# COSMIC
# MS
# VS
# Center
# Chromosome
# Start Pos
# End Pos
# Ref
# Var
# HGVSg
# HGVSc
# Allele Freq (T)
# Allele Freq (N)
# Variant Reads
# Ref Reads
# Variant Reads (Normal)
# Ref Reads (Normal)
# # Mut in Sample
# Exon
# gnomAD
# ClinVar
# dbSNP
# SIGNAL
# Adjuvant Chemotherapy
# Adjuvant Treatment
# diagnosis_age
# ER Status By IHC
# Followup (years)
# Fusion Status
# Genomic Alterations
# IHC-HER2
# Local Regional Recurrence
# Metastatic Site
# Metastatic tumor indicator
# MYB or MYBL1 Fusion
# MYB-NFIB Fusion Gene Copy Number Alterations
# MYB-NFIB FISH
# MYB-NFIB Fusion Gene Non-synonymous Mutations
# MYB-NFIB Rearrangement
# Neoadjuvant Chemotherapy
# Oncotree Code
# Overall Patient Histology
# Platform
# Primary Tumor Site
# PR status by ihc
# Radiation Therapy
# Number of Samples Per Patient
# Sample Type
# Sex
# Somatic Status
# Study
# Time to Metastasis (months)
# TMB (nonsynonymous)
# Tumor Size
# Tumor Stage
# Type of Surgery
# Patient's Vital Status
# Ethnicity Category
# Neoplasm Histologic Type Name
# Mean Coverage (x)
# Total Number of Somatic Mutations
# Surgery
# Angiolymphatic Invasion
# Neoplasm American Joint Committee on Cancer Clinical Distant Metastasis M Stage
# Neoplasm American Joint Committee on Cancer Clinical Regional Lymph Node N Stage
# ER Status
# Estimated Tumor Cellularity
# Neoplasm Histologic Grade
# Histological Type
# IHC_BASAL
# IHC_CK5/6
# IHC_EGFR
# PAM50 subtype
# PR Status
# Fraction Genome Altered
# Sample Class
# Sequencing Type
# Country
# HER2 Amplification Status
# HER2 Status
# Menopause Status
# Nonsilent Mutation Rate
# Ploidy
# Purity
# Silent Mutation Rate
# Stage
# Subtype
# APOBEC Signature
# Cancer type
# CD3 TILS Counts
# CD3 TILS Status
# Chromosome INstability index CIN
# CIBERSORT Absolute Score
# ERBB2 Gene Amplified
# ERBB2 Proteogenomic Status
# ERBB2 Updated Clinical Status
# ER Updated Clinical Status
# ESTIMATE Immune Score
# ESTIMATE Stromal Score
# ESTIMATE TumorPurity
# Ischemia Time in Minutes
# NMF Cluster
# NMF Cluster Membership Score
# Number of non synonymous Mutations
# Oncotree code
# PAM50
# PR Clinical Status
# Stemness Score
# TMT Channel
# TMT Plex
# TNBC Updated Clinical Status
# TOP2A Gene Amplified
# TOP2A Proteogenomic Status
# xCell Immune Score
# xCell Stromal Score
# Disease Status
# Overall Survival (Months)
# status_pacient
# Overall Survival Status
# Race Category
# Sample Collection Method
# Specimen Preservation Type
# Specimen Site
# Specimen Type
# Time to Last Followup
# Study ID
# ER
# HER2
# Diagnosis P Stage
# Gene Panel
# Histology
# MSI Comment
# MSI Score
# MSI Type
# Progress Free Survival (Months)
# Progression Free Status
# Reason Stop
# Religion
# Sample coverage
# Sample Status
# SO comments
# Tumor Mutation Burden
# Tumor Purity
# Treatment Line
# Treatment Location
# Treatment Regimen
# MedR Age at Diagnosis
# PRD Ever Cancer Location Ascites
# PRD Ever Cancer Location Axillary Lymph Node
# PRD Ever Cancer Location Bone
# PRD Ever Cancer Location Brain
# PRD Ever Cancer Location Breast
# PRD Ever Cancer Location Chest Wall
# PRD Ever Cancer Location Liver
# PRD Ever Cancer Location Lung
# PRD Ever Cancer Location Other Lymph Node
# PRD Ever Cancer Location Ovary
# PRD Ever Cancer Location Pleural Effusion
# PRD Ever Cancer Location Skin
# PATH CEP17 Copy
# PATH HER2 Copy
# PATH HER2 CEP17 Ratio
# PATH DCIS Reported
# PATH Estrogen Receptor Status
# PATH Sample Grade
# PATH HER2 FISH
# PATH HER2 IHC
# PATH HER2 Status
# PATH Sample Histology
# PATH Ki67 Percentage
# PATH LCIS Reported
# PATH Procedure Location
# PATH Sample notes
# PATH Estrogen Receptor Percentage
# PATH Progesterone Receptor Percentage
# PATH Progesterone Receptor Status
# PATH Breast Procedure Laterality
# PATH Sample Collection Time
# PATH Procedure Type
# PATH Sample In Metastatic Setting
# MedR Time to Metastatic Diagnosis (Calculated Days)
# MedR Time to Metastatic Diagnosis (Calculated Months)
# PATH Sample Treatment Naive
# PRD Histology IDC
# PRD Histology ILC
# PRD Histology MIDLC
# PRD Histology Rare Subtype
# MedR DCIS Present in Surgical Biopsy
# MedR Diagnosed by Screening
# PRD Cancer Location at Mets Diagnosis Bone
# PRD Cancer Location at Mets Diagnosis Ascites
# PRD Cancer Location at Mets Diagnosis Axillary Lymph Node
# PRD Cancer Location at Mets Diagnosis Brain
# PRD Cancer Location at Mets Diagnosis Breast
# PRD Cancer Location at Mets Diagnosis Chest Wall
# PRD Cancer Location at Mets Diagnosis Liver
# PRD Cancer Location at Mets Diagnosis Lung
# PRD Cancer Location at Mets Diagnosis Other Lymph Node
# PRD Cancer Location at Mets Diagnosis Ovary
# PRD Cancer Location at Mets Diagnosis Pleural Effusion
# PRD Cancer Location at Mets Diagnosis Skin
# MedR Diagnosed While Breastfeeding
# MedR Diagnostic CEP17 Copy
# MedR Diagnostic ER Status
# MedR Diagnostic Grade
# MedR Diagnostic HER2 FISH
# MedR Diagnostic HER2 IHC
# MedR Diagnostic HER2 Status
# MedR Diagnostic HER2 Copy
# MedR Diagnostic HER2 Ratio
# MedR Diagnostic Histology
# MedR Diagnosis Location
# MedR Diagnostic ER %
# MedR Diagnostic PR %
# MedR Diagnostic PR Status
# MedR Diagnosed While Pregnant
# MedR Diagnosis Laterality
# MedR Stage at Diagnosis
# MedR Diagnostic Procedure
# MedR BRCA1 Mutation
# MedR BRCA2 Mutation
# MedR PALB2 Mutation
# PRD Ever HER2 Positive
# PRD Hispanic
# PRD Ever Hormone Receptor Positive
# PRD Ever Inflammatory
# MedR LCIS Present in Surgical Biopsy
# MedR Local Regional Recurrence Location
# MedR Menopausal Status at Diagnosis
# MedR Ever Metastatic Sites
# MedR Ever Adrenal Gland Mets
# MedR Ever Ascites Mets
# MedR Ever Bone Mets
# MedR Ever Brain/CNS Mets
# MedR Ever Chest Wall Mets
# MedR Ever Distant Lymph Node Mets
# MedR Ever Intraabdominal Mets
# MedR Ever Liver Mets
# MedR Ever Lung Mets
# MedR Ever Ovary Mets
# MedR Ever Pleural Effusion Mets
# MedR Ever Skin Mets
# MedR Ever Soft Tissue Mets
# MedR Metastatic Sites at Metastatic Diagnosis
# MedR Adrenal Gland Mets at Mets Dx
# MedR Ascites Mets at Mets Dx
# MedR Bone Mets at Mets Dx
# MedR Brain/CNS Mets at Mets Dx
# MedR Chest Wall Mets at Mets Dx
# MedR Distant Lymph Node Mets at Mets Dx
# MedR Intraabdominal Mets at Mets Dx
# MedR Liver Mets at Mets Dx
# MedR Lung Mets at Mets Dx
# MedR Ovary Mets at Mets Dx
# MedR Pleural Effusion Mets at Mets Dx
# MedR Skin Mets at Mets Dx
# MedR Soft Tissue Mets at Mets Dx
# MedR Patient Notes
# PRD Race
# Sample Timepoint
# MedR Surgery at Diagnosis
# MedR HER2 CEP17 Copy Number of Surgical Biopsy
# MedR ER Status of Surgical Biopsy
# MedR Grade of Surgical Biopsy
# MedR HER2 FISH Status of Surgical Biopsy
# MedR HER2 IHC Status of Surgical Biopsy
# MedR HER2 Overall Status of Surgical Biopsy
# MedR HER2 Copy Number of Surgical Biopsy
# MedR HER2 Ratio of Surgical Biopsy
# MedR ER Percentage of Surgical Biopsy
# MedR PR Percentage of Surgical Biopsy
# MedR PR Status of Surgical Biopsy
# MedR Stage of Surgical Biopsy
# PRD Any Therapy More Than 2 Years
# PRD Ever Triple Negative
# PATH TUMOR FRACTION
# MedR Adjuvant Radiation
# MedR Age at Diagnosis.1
# PRD Any Therapy More Than 2 Years.1
# MedR Diagnostic CEP17 Copy.1
# MedR Diagnostic HER2 Copy.1
# MedR Ever Metastatic Sites.1
# PRD Ever HER2 Positive.1
# PRD Ever Hormone Receptor Positive.1
# PRD Ever Inflammatory.1
# MedR Metastatic Sites at Metastatic Diagnosis.1
# MedR Ever Regional Lymph Node Mets
# MedR Ever Unknown Mets
# MedR Regional Lymph Node Mets at Mets Dx
# MedR Unknown Mets at Mets Dx
# MedR N Stage at Diagnosis
# MedR Patient Notes.1
# PRD Race.1
# PRD Ever Triple Negative.1
# MedR T Stage at Diagnosis
# PRD More Than 2 Years Aromatase Inhibitors
# PRD More Than 2 Years Alkylating Agent
# PRD More Than 2 Years Anthracycline
# PRD More Than 2 Years Anti-HER2
# PRD More Than 2 Years Capecitabine
# PRD More Than 2 Years CDK4/6 Inhibitor
# PRD More Than 2 Years Fulvestrant
# PRD More Than 2 Years Tamoxifen
# PRD More Than 2 Years Taxane
# PRD More Than 2 Years VEGF Inhibitor
# Type of Breast Surgery
# Cellularity
# Chemotherapy
# Pam50 + Claudin-low subtype
# Cohort
# ER status measured by IHC
# HER2 status measured by SNP6
# Tumor Other Histologic Subtype
# Hormone Therapy
# Inferred Menopausal State
# Integrative Cluster
# Primary Tumor Laterality
# Lymph nodes examined positive
# Nottingham prognostic index
# Radio Therapy
# Relapse Free Status (Months)
# Relapse Free Status
# 3-Gene classifier subtype
# Best Response to Therapy
# block accession
# Comments
# months on study
# Months on Treatment
# Other Patient ID
# patient study id
# PIK3CA Mutation
# reason for tx discontinuation
# Sample origin
# snapshot mutations
# Status
# study arm
# therapy
# Treatment best response
# Aberrant Cell Fraction
# Histopathology
# Mitotic Count
# Mitotic Score
# Pleomorphism Score
# Tubule Score
# Tumor Ploidy
# Center of sequencing
# Cytolytic Activity Score
# Histology.1
# Immunohistochemistry Subtype
# TNM Stage
# Menopausal Status At Diagnosis
# Mutation Burden
# Subtype Consensus
# Chemotherapy.1
# American Joint Committee on Cancer Metastasis Stage Code
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code
# Neoplasm Disease Stage American Joint Committee on Cancer Code
# American Joint Committee on Cancer Publication Version Type
# American Joint Committee on Cancer Tumor Stage Code
# Brachytherapy first reference point administered total dose
# Cent17 Copy Number
# Neoplasm American Joint Committee on Cancer Clinical Group Stage
# Neoplasm American Joint Committee on Cancer Clinical Primary Tumor T Stage
# Days to Sample Collection.
# Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value
# days_to_patient_progression_free
# Days to Sample Procurement
# days_to_tumor_progression
# Disease Free (Months)
# Disease Free Status
# Disease code
# ER positivity scale other
# ER positivity scale used
# ER Status IHC Percent Positive
# Lymphomatous Extranodal Site Involvement Indicator
# First surgical procedure other
# Form completion date
# HER2 and cent17 cells count
# HER2 and cent17 scale other
# HER2 cent17 counted cells count
# HER2 cent17 ratio
# HER2 copy number
# HER2 fish method
# HER2 fish status
# HER2 ihc percent positive
# HER2 ihc score
# HER2 positivity method text
# HER2 positivity scale other
# Neoadjuvant Therapy Type Administered Prior To Resection Text
# Prior Cancer Diagnosis Occurence
# ICD-10 Classification
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code
# IHC Score
# Informed consent verified
# Year Cancer Initial Diagnosis
# Is FFPE
# Longest Dimension
# Primary Lymph Node Presentation Assessment Ind-3
# Positive Finding Lymph Node Hematoxylin and Eosin Staining Microscopy Count
# Positive Finding Lymph Node Keratin Immunohistochemistry Staining Method Count
# Lymph Node(s) Examined Number
# Margin status reexcision
# Metastatic Site Other
# Patient Metastatic Sites
# First Pathologic Diagnosis Biospecimen Acquisition Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Other Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Method Type.1
# Micromet detection by ihc
# New Neoplasm Event Post Initial Therapy Indicator
# Nte cent17 HER2 other scale
# Nte cent 17 HER2 ratio
# Nte cent 17 signal number
# Nte er ihc intensity score
# Nte er positivity define method
# Nte er positivity other scale
# Nte er status
# Nte er status ihc positive
# Nte HER2 fish define method
# Nte HER2 fish status
# Nte HER2 positivity ihc score
# Nte HER2 positivity method
# Nte HER2 positivity other scale
# Nte HER2 signal number
# Nte HER2 status
# Nte HER2 status ihc positive
# Nte pr ihc intensity score
# Nte pr positivity define method
# Nte pr positivity other scale
# Nte pr status by ihc
# Nte pr status ihc positive
# Oct embedded
# Specimen Collection Method
# Other Sample ID
# Pathology Report File Name
# Pathology report uuid
# Disease Surgical Margin Status
# Adjuvant Postoperative Pharmaceutical Therapy Administered Indicator
# Primary Other Site of Disease Name
# Patient Primary Tumor Site
# Project code
# Tissue Prospective Collection Indicator
# PR positivity define method
# PR positivity ihc intensity score
# PR positivity scale other
# PR positivity scale used
# PR status ihc percent positive
# Did patient start adjuvant postoperative radiotherapy?
# Tissue Retrospective Collection Indicator
# Sample Initial Weight
# Sample type id
# Shortest Dimension
# Tumor Tissue Site
# Specimen Current Weight
# Specimen Freezing Means
# Specimen Second Longest Dimension
# Stage Other
# Staging System
# Staging System.1
# Surgery for positive margins
# Surgery for positive margins other
# Surgical procedure first
# Time between clamping and freezing
# Time between excision and freezing
# Tissue Source Site
# Person Neoplasm Status
# Vial number
# Aneuploidy Score
# Buffa Hypoxia Score
# TCGA PanCanAtlas Cancer Type Acronym
# Last Communication Contact from Initial Pathologic Diagnosis Date
# Birth from Initial Pathologic Diagnosis Date
# Months of disease-specific survival
# Disease-specific Survival status
# Genetic Ancestry Label
# In PanCan Pathway Analysis
# MSI MANTIS Score
# MSIsensor Score
# American Joint Committee on Cancer Metastasis Stage Code.1
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code.1
# American Joint Committee on Cancer Tumor Stage Code.1
# Person Neoplasm Cancer Status
# Primary Lymph Node Presentation Assessment
# Prior Diagnosis
# Ragnum Hypoxia Score
# Tissue Prospective Collection Indicator.1
# Tissue Retrospective Collection Indicator.1
# Tissue Source Site Code
# Tumor Disease Anatomic Site
# Tumor Type
# Patient Weight
# Winter Hypoxia Score
# CN Cluster
# Converted Stage
# Integrated Clusters (no exp)
# Integrated Clusters (unsup exp)
# Integrated Clusters (with PAM50)
# Metastasis
# Metastasis-Coded
# Methylation Cluster
# MIRNA Cluster
# Node
# Node-Coded
# RPPA Cluster
# SigClust Intrinsic mRNA
# SigClust Unsupervised mRNA
# Survival Data Form
# Tumor--T1 Coded
# Death from Initial Pathologic Diagnosis Date
# Days to Last Followup
# Nte er status ihc positive.1
# Nte HER2 status ihc positive.1
# Nte pr status ihc positive.1
# Alpelisib Dose (mg)
# Alpelisib Scheduling
# Breast Cancer Subtype
# Clinical Benefit
# Endocrine Therapy
# Measurable Disease
# Off Study Reason
# Patient Display Name
# PIK3CA Pre Treatment Tumor Mutation
# PIK3CA Pre Treatment Tumor
# Best RECIST Response
# Sample Collection Time
# Tumor Sequencing Platform
# Treatment Arm
# Weeks on Study
# Age at Which Sequencing was Reported (Years)
# Patient Current Age
# Disease Free Event
# ER PCT Primary
# ER Status of the Primary
# HER2 FISH Status of Sequenced Sample
# HER2 FISH Ratio Value of Sequenced Sample
# HER2 FISH Ratio Primary
# HER2 IHC Status Primary
# HER2 IHC Status of Sequenced Sample
# HER2 IHC Score Primary
# HER2 Primary Status
# Overall HR Status of Sequenced Sample
# Invasive Carcinoma Diagnosis Age
# Time to Diagnosis Invasive Carcinoma
# Last Communication Contact
# Metastatic Disease at Last Follow-up
# Metastatic Recurrence Time
# M Stage
# NGS Sample Collection Time Period
# N Stage
# Overall HER2 Status of Sequenced Sample
# Overall Patient HER2 Status
# Overall Patient HR Status
# Overall Patient Receptor Status
# Overall Primary Tumor Grade
# Primary Nuclear Grade
# Prior Breast Primary
# Prior Local Recurrence
# PR PCT Primary
# PR Status of the Primary
# Receptor Status Primary
# Site of Sample
# Stage At Diagnosis
# Time To Death (Months)
# Tumor Sample Histology
# Tumor Tissue Origin
# T Stage
# Archer Panel
# Institute Source
# Patient Display Name.1
# Sample Display Name
# Tumor Site
# Tumor Size (cm)

# %% [markdown]
# *Mutación mama BRCA2*

# %%
brca2_mama_mutation = pd.read_csv('https://raw.githubusercontent.com/PaolaSantiago00/C-ncer-de-mama/main/BRCA2_mama%20(separado).csv')

brca2_mama_mutation.head()
# Out:
#                                     Study of Origin        Sample ID  \
# 0   Non-CDH1 Invasive Lobular Carcinoma (MSK, 2023)            CDW21
# 1  Metastatic Breast Cancer (INSERM, PLoS Med 2016)           MBC_45
# 2  Metastatic Breast Cancer (INSERM, PLoS Med 2016)           MBC_50
# 3  Metastatic Breast Cancer (INSERM, PLoS Med 2016)           MBC_40
# 4     Breast Invasive Carcinoma (TCGA, Nature 2012)  TCGA-A8-A08L-01
#
#      Cancer Type               Cancer Type Detailed Protein Change  \
# 0  Breast Cancer  Breast Invasive Lobular Carcinoma    Q2506Sfs*21
# 1  Breast Cancer          Invasive Breast Carcinoma          E654*
# 2  Breast Cancer          Invasive Breast Carcinoma    X637_splice
# 3  Breast Cancer          Invasive Breast Carcinoma      P190Gfs*3
# 4  Breast Cancer          Invasive Breast Carcinoma   X2602_splice
#
#                                    Annotation OncoKB CancerHotspot  \
# 0  OncoKB: Likely Oncogenic, level_3a, resistance NA            no
# 1  OncoKB: Likely Oncogenic, level_3a, resistance NA            no
# 2  OncoKB: Likely Oncogenic, level_3a, resistance NA            no
# 3  OncoKB: Likely Oncogenic, level_3a, resistance NA            no
# 4  OncoKB: Likely Oncogenic, level_3a, resistance NA            no
#
#   Functional Impact MutationAssesor  Functional Impact MutationAssesor Score  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#   Functional Impact SIFT  ...  Time To Death (Months) Tumor Sample Histology  \
# 0                    NaN  ...                     NaN                    NaN
# 1                    NaN  ...                     NaN                    NaN
# 2                    NaN  ...                     NaN                    NaN
# 3                    NaN  ...                     NaN                    NaN
# 4                    NaN  ...                     NaN                    NaN
#
#    Tumor Tissue Origin T Stage Archer Panel Institute Source  \
# 0                  NaN     NaN           NO            MSKCC
# 1                  NaN     NaN          NaN              NaN
# 2                  NaN     NaN          NaN              NaN
# 3                  NaN     NaN          NaN              NaN
# 4                  NaN     NaN          NaN              NaN
#
#    Patient Display Name.1 Sample Display Name Tumor Site Tumor Size (cm)
# 0               P-0026032   P-0026032-T01-IM6        NaN             NaN
# 1                     NaN                 NaN        NaN             NaN
# 2                     NaN                 NaN        NaN             NaN
# 3                     NaN                 NaN        NaN             NaN
# 4                     NaN                 NaN        NaN             NaN
#
# [5 rows x 588 columns]

# %%
#Investigamos con cuantas filas y columnas cuenta el dataset
num_filas_np, num_columnas_np = brca2_mama_mutation.shape

print("Número de filas:", num_filas_np)
print("Número de columnas:", num_columnas_np)
# Out:
# Número de filas: 356
# Número de columnas: 588

# %%
# Obtener e imprimir el nombre de todas las columnas
print("Nombres de las columnas:")
for nombre_columna in brca2_mama_mutation.columns:
    print(nombre_columna)
# Out:
# Nombres de las columnas:
# Study of Origin
# Sample ID
# Cancer Type
# Cancer Type Detailed
# Protein Change
# Annotation OncoKB
# CancerHotspot
# Functional Impact MutationAssesor
# Functional Impact MutationAssesor Score
# Functional Impact SIFT
# Functional Impact SIFT Score
# Functional Impact Polyphen-2
# Functional Impact Polyphen-2 Score
# Mutation Type
# Variant Type
# Copy #
# COSMIC
# MS
# VS
# Center
# Chromosome
# Start Pos
# End Pos
# Ref
# Var
# HGVSg
# HGVSc
# Allele Freq (T)
# Allele Freq (N)
# Variant Reads
# Ref Reads
# Variant Reads (Normal)
# Ref Reads (Normal)
# # Mut in Sample
# Exon
# gnomAD
# ClinVar
# dbSNP
# SIGNAL
# Adjuvant Chemotherapy
# Adjuvant Treatment
# Diagnosis Age
# ER Status By IHC
# Followup (years)
# Fusion Status
# Genomic Alterations
# IHC-HER2
# Local Regional Recurrence
# Metastatic Site
# Metastatic tumor indicator
# MYB or MYBL1 Fusion
# MYB-NFIB Fusion Gene Copy Number Alterations
# MYB-NFIB FISH
# MYB-NFIB Fusion Gene Non-synonymous Mutations
# MYB-NFIB Rearrangement
# Neoadjuvant Chemotherapy
# Oncotree Code
# Overall Patient Histology
# Platform
# Primary Tumor Site
# PR status by ihc
# Radiation Therapy
# Number of Samples Per Patient
# Sample Type
# Sex
# Somatic Status
# Study
# Time to Metastasis (months)
# TMB (nonsynonymous)
# Tumor Size
# Tumor Stage
# Type of Surgery
# Patient's Vital Status
# Ethnicity Category
# Neoplasm Histologic Type Name
# Mean Coverage (x)
# Total Number of Somatic Mutations
# Surgery
# Angiolymphatic Invasion
# Neoplasm American Joint Committee on Cancer Clinical Distant Metastasis M Stage
# Neoplasm American Joint Committee on Cancer Clinical Regional Lymph Node N Stage
# ER Status
# Estimated Tumor Cellularity
# Neoplasm Histologic Grade
# Histological Type
# IHC_BASAL
# IHC_CK5/6
# IHC_EGFR
# PAM50 subtype
# PR Status
# Fraction Genome Altered
# Sample Class
# Sequencing Type
# Country
# HER2 Amplification Status
# HER2 Status
# Menopause Status
# Nonsilent Mutation Rate
# Ploidy
# Purity
# Silent Mutation Rate
# Stage
# Subtype
# APOBEC Signature
# Cancer type
# CD3 TILS Counts
# CD3 TILS Status
# Chromosome INstability index CIN
# CIBERSORT Absolute Score
# ERBB2 Gene Amplified
# ERBB2 Proteogenomic Status
# ERBB2 Updated Clinical Status
# ER Updated Clinical Status
# ESTIMATE Immune Score
# ESTIMATE Stromal Score
# ESTIMATE TumorPurity
# Ischemia Time in Minutes
# NMF Cluster
# NMF Cluster Membership Score
# Number of non synonymous Mutations
# Oncotree code
# PAM50
# PR Clinical Status
# Stemness Score
# TMT Channel
# TMT Plex
# TNBC Updated Clinical Status
# TOP2A Gene Amplified
# TOP2A Proteogenomic Status
# xCell Immune Score
# xCell Stromal Score
# Disease Status
# Overall Survival (Months)
# Overall Survival Status
# Patient Tumor Grade
# Race Category
# Sample Collection Method
# Specimen Preservation Type
# Specimen Site
# Specimen Type
# Time to Last Followup
# Study ID
# ER
# HER2
# Diagnosis P Stage
# Gene Panel
# Histology
# MSI Comment
# MSI Score
# MSI Type
# Progress Free Survival (Months)
# Progression Free Status
# Reason Stop
# Religion
# Sample coverage
# Sample Status
# SO comments
# Tumor Mutation Burden
# Tumor Purity
# Treatment Line
# Treatment Location
# Treatment Regimen
# MedR Age at Diagnosis
# PRD Ever Cancer Location Ascites
# PRD Ever Cancer Location Axillary Lymph Node
# PRD Ever Cancer Location Bone
# PRD Ever Cancer Location Brain
# PRD Ever Cancer Location Breast
# PRD Ever Cancer Location Chest Wall
# PRD Ever Cancer Location Liver
# PRD Ever Cancer Location Lung
# PRD Ever Cancer Location Other Lymph Node
# PRD Ever Cancer Location Ovary
# PRD Ever Cancer Location Pleural Effusion
# PRD Ever Cancer Location Skin
# PATH CEP17 Copy
# PATH HER2 Copy
# PATH HER2 CEP17 Ratio
# PATH DCIS Reported
# PATH Estrogen Receptor Status
# PATH Sample Grade
# PATH HER2 FISH
# PATH HER2 IHC
# PATH HER2 Status
# PATH Sample Histology
# PATH Ki67 Percentage
# PATH LCIS Reported
# PATH Procedure Location
# PATH Sample notes
# PATH Estrogen Receptor Percentage
# PATH Progesterone Receptor Percentage
# PATH Progesterone Receptor Status
# PATH Breast Procedure Laterality
# PATH Sample Collection Time
# PATH Procedure Type
# PATH Sample In Metastatic Setting
# MedR Time to Metastatic Diagnosis (Calculated Days)
# MedR Time to Metastatic Diagnosis (Calculated Months)
# PATH Sample Treatment Naive
# PRD Histology IDC
# PRD Histology ILC
# PRD Histology MIDLC
# PRD Histology Rare Subtype
# MedR DCIS Present in Surgical Biopsy
# MedR Diagnosed by Screening
# PRD Cancer Location at Mets Diagnosis Bone
# PRD Cancer Location at Mets Diagnosis Ascites
# PRD Cancer Location at Mets Diagnosis Axillary Lymph Node
# PRD Cancer Location at Mets Diagnosis Brain
# PRD Cancer Location at Mets Diagnosis Breast
# PRD Cancer Location at Mets Diagnosis Chest Wall
# PRD Cancer Location at Mets Diagnosis Liver
# PRD Cancer Location at Mets Diagnosis Lung
# PRD Cancer Location at Mets Diagnosis Other Lymph Node
# PRD Cancer Location at Mets Diagnosis Ovary
# PRD Cancer Location at Mets Diagnosis Pleural Effusion
# PRD Cancer Location at Mets Diagnosis Skin
# MedR Diagnosed While Breastfeeding
# MedR Diagnostic CEP17 Copy
# MedR Diagnostic ER Status
# MedR Diagnostic Grade
# MedR Diagnostic HER2 FISH
# MedR Diagnostic HER2 IHC
# MedR Diagnostic HER2 Status
# MedR Diagnostic HER2 Copy
# MedR Diagnostic HER2 Ratio
# MedR Diagnostic Histology
# MedR Diagnosis Location
# MedR Diagnostic ER %
# MedR Diagnostic PR %
# MedR Diagnostic PR Status
# MedR Diagnosed While Pregnant
# MedR Diagnosis Laterality
# MedR Stage at Diagnosis
# MedR Diagnostic Procedure
# MedR BRCA1 Mutation
# MedR BRCA2 Mutation
# MedR PALB2 Mutation
# PRD Ever HER2 Positive
# PRD Hispanic
# PRD Ever Hormone Receptor Positive
# PRD Ever Inflammatory
# MedR LCIS Present in Surgical Biopsy
# MedR Local Regional Recurrence Location
# MedR Menopausal Status at Diagnosis
# MedR Ever Metastatic Sites
# MedR Ever Adrenal Gland Mets
# MedR Ever Ascites Mets
# MedR Ever Bone Mets
# MedR Ever Brain/CNS Mets
# MedR Ever Chest Wall Mets
# MedR Ever Distant Lymph Node Mets
# MedR Ever Intraabdominal Mets
# MedR Ever Liver Mets
# MedR Ever Lung Mets
# MedR Ever Ovary Mets
# MedR Ever Pleural Effusion Mets
# MedR Ever Skin Mets
# MedR Ever Soft Tissue Mets
# MedR Metastatic Sites at Metastatic Diagnosis
# MedR Adrenal Gland Mets at Mets Dx
# MedR Ascites Mets at Mets Dx
# MedR Bone Mets at Mets Dx
# MedR Brain/CNS Mets at Mets Dx
# MedR Chest Wall Mets at Mets Dx
# MedR Distant Lymph Node Mets at Mets Dx
# MedR Intraabdominal Mets at Mets Dx
# MedR Liver Mets at Mets Dx
# MedR Lung Mets at Mets Dx
# MedR Ovary Mets at Mets Dx
# MedR Pleural Effusion Mets at Mets Dx
# MedR Skin Mets at Mets Dx
# MedR Soft Tissue Mets at Mets Dx
# MedR Patient Notes
# PRD Race
# Sample Timepoint
# MedR Surgery at Diagnosis
# MedR HER2 CEP17 Copy Number of Surgical Biopsy
# MedR ER Status of Surgical Biopsy
# MedR Grade of Surgical Biopsy
# MedR HER2 FISH Status of Surgical Biopsy
# MedR HER2 IHC Status of Surgical Biopsy
# MedR HER2 Overall Status of Surgical Biopsy
# MedR HER2 Copy Number of Surgical Biopsy
# MedR HER2 Ratio of Surgical Biopsy
# MedR ER Percentage of Surgical Biopsy
# MedR PR Percentage of Surgical Biopsy
# MedR PR Status of Surgical Biopsy
# MedR Stage of Surgical Biopsy
# PRD Any Therapy More Than 2 Years
# PRD Ever Triple Negative
# PATH TUMOR FRACTION
# MedR Adjuvant Radiation
# MedR Age at Diagnosis.1
# PRD Any Therapy More Than 2 Years.1
# MedR Diagnostic CEP17 Copy.1
# MedR Diagnostic HER2 Copy.1
# MedR Ever Metastatic Sites.1
# PRD Ever HER2 Positive.1
# PRD Ever Hormone Receptor Positive.1
# PRD Ever Inflammatory.1
# MedR Metastatic Sites at Metastatic Diagnosis.1
# MedR Ever Regional Lymph Node Mets
# MedR Ever Unknown Mets
# MedR Regional Lymph Node Mets at Mets Dx
# MedR Unknown Mets at Mets Dx
# MedR N Stage at Diagnosis
# MedR Patient Notes.1
# PRD Race.1
# PRD Ever Triple Negative.1
# MedR T Stage at Diagnosis
# PRD More Than 2 Years Aromatase Inhibitors
# PRD More Than 2 Years Alkylating Agent
# PRD More Than 2 Years Anthracycline
# PRD More Than 2 Years Anti-HER2
# PRD More Than 2 Years Capecitabine
# PRD More Than 2 Years CDK4/6 Inhibitor
# PRD More Than 2 Years Fulvestrant
# PRD More Than 2 Years Tamoxifen
# PRD More Than 2 Years Taxane
# PRD More Than 2 Years VEGF Inhibitor
# Type of Breast Surgery
# Cellularity
# Chemotherapy
# Pam50 + Claudin-low subtype
# Cohort
# ER status measured by IHC
# HER2 status measured by SNP6
# Tumor Other Histologic Subtype
# Hormone Therapy
# Inferred Menopausal State
# Integrative Cluster
# Primary Tumor Laterality
# Lymph nodes examined positive
# Nottingham prognostic index
# Radio Therapy
# Relapse Free Status (Months)
# Relapse Free Status
# 3-Gene classifier subtype
# Best Response to Therapy
# block accession
# Comments
# months on study
# Months on Treatment
# Other Patient ID
# patient study id
# PIK3CA Mutation
# reason for tx discontinuation
# Sample origin
# snapshot mutations
# Status
# study arm
# therapy
# Treatment best response
# Aberrant Cell Fraction
# Histopathology
# Mitotic Count
# Mitotic Score
# Pleomorphism Score
# Tubule Score
# Tumor Ploidy
# Center of sequencing
# Cytolytic Activity Score
# Histology
# Immunohistochemistry Subtype
# TNM Stage
# Menopausal Status At Diagnosis
# Mutation Burden
# Subtype Consensus
# Chemotherapy.1
# American Joint Committee on Cancer Metastasis Stage Code
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code
# Neoplasm Disease Stage American Joint Committee on Cancer Code
# American Joint Committee on Cancer Publication Version Type
# American Joint Committee on Cancer Tumor Stage Code
# Brachytherapy first reference point administered total dose
# Cent17 Copy Number
# Neoplasm American Joint Committee on Cancer Clinical Group Stage
# Neoplasm American Joint Committee on Cancer Clinical Primary Tumor T Stage
# Days to Sample Collection.
# Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value
# days_to_patient_progression_free
# Days to Sample Procurement
# days_to_tumor_progression
# Disease Free (Months)
# Disease Free Status
# Disease code
# ER positivity scale other
# ER positivity scale used
# ER Status IHC Percent Positive
# Lymphomatous Extranodal Site Involvement Indicator
# First surgical procedure other
# Form completion date
# HER2 and cent17 cells count
# HER2 and cent17 scale other
# HER2 cent17 counted cells count
# HER2 cent17 ratio
# HER2 copy number
# HER2 fish method
# HER2 fish status
# HER2 ihc percent positive
# HER2 ihc score
# HER2 positivity method text
# HER2 positivity scale other
# Neoadjuvant Therapy Type Administered Prior To Resection Text
# Prior Cancer Diagnosis Occurence
# ICD-10 Classification
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code
# International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code
# IHC Score
# Informed consent verified
# Year Cancer Initial Diagnosis
# Is FFPE
# Longest Dimension
# Primary Lymph Node Presentation Assessment Ind-3
# Positive Finding Lymph Node Hematoxylin and Eosin Staining Microscopy Count
# Positive Finding Lymph Node Keratin Immunohistochemistry Staining Method Count
# Lymph Node(s) Examined Number
# Margin status reexcision
# Metastatic Site Other
# Patient Metastatic Sites
# First Pathologic Diagnosis Biospecimen Acquisition Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Other Method Type
# First Pathologic Diagnosis Biospecimen Acquisition Method Type.1
# Micromet detection by ihc
# New Neoplasm Event Post Initial Therapy Indicator
# Nte cent17 HER2 other scale
# Nte cent 17 HER2 ratio
# Nte cent 17 signal number
# Nte er ihc intensity score
# Nte er positivity define method
# Nte er positivity other scale
# Nte er status
# Nte er status ihc positive
# Nte HER2 fish define method
# Nte HER2 fish status
# Nte HER2 positivity ihc score
# Nte HER2 positivity method
# Nte HER2 positivity other scale
# Nte HER2 signal number
# Nte HER2 status
# Nte HER2 status ihc positive
# Nte pr ihc intensity score
# Nte pr positivity define method
# Nte pr positivity other scale
# Nte pr status by ihc
# Nte pr status ihc positive
# Oct embedded
# Specimen Collection Method
# Other Sample ID
# Pathology Report File Name
# Pathology report uuid
# Disease Surgical Margin Status
# Adjuvant Postoperative Pharmaceutical Therapy Administered Indicator
# Primary Other Site of Disease Name
# Patient Primary Tumor Site
# Project code
# Tissue Prospective Collection Indicator
# PR positivity define method
# PR positivity ihc intensity score
# PR positivity scale other
# PR positivity scale used
# PR status ihc percent positive
# Did patient start adjuvant postoperative radiotherapy?
# Tissue Retrospective Collection Indicator
# Sample Initial Weight
# Sample type id
# Shortest Dimension
# Tumor Tissue Site
# Specimen Current Weight
# Specimen Freezing Means
# Specimen Second Longest Dimension
# Stage Other
# Staging System
# Staging System.1
# Surgery for positive margins
# Surgery for positive margins other
# Surgical procedure first
# Time between clamping and freezing
# Time between excision and freezing
# Tissue Source Site
# Person Neoplasm Status
# Vial number
# Aneuploidy Score
# Buffa Hypoxia Score
# TCGA PanCanAtlas Cancer Type Acronym
# Last Communication Contact from Initial Pathologic Diagnosis Date
# Birth from Initial Pathologic Diagnosis Date
# Months of disease-specific survival
# Disease-specific Survival status
# Genetic Ancestry Label
# In PanCan Pathway Analysis
# MSI MANTIS Score
# MSIsensor Score
# American Joint Committee on Cancer Metastasis Stage Code.1
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code.1
# American Joint Committee on Cancer Tumor Stage Code.1
# Person Neoplasm Cancer Status
# Primary Lymph Node Presentation Assessment
# Prior Diagnosis
# Ragnum Hypoxia Score
# Tissue Prospective Collection Indicator.1
# Tissue Retrospective Collection Indicator.1
# Tissue Source Site Code
# Tumor Disease Anatomic Site
# Tumor Type
# Patient Weight
# Winter Hypoxia Score
# CN Cluster
# Converted Stage
# Integrated Clusters (no exp)
# Integrated Clusters (unsup exp)
# Integrated Clusters (with PAM50)
# Metastasis
# Metastasis-Coded
# Methylation Cluster
# MIRNA Cluster
# Node
# Node-Coded
# RPPA Cluster
# SigClust Intrinsic mRNA
# SigClust Unsupervised mRNA
# Survival Data Form
# Tumor--T1 Coded
# Death from Initial Pathologic Diagnosis Date
# Days to Last Followup
# Nte er status ihc positive.1
# Nte HER2 status ihc positive.1
# Nte pr status ihc positive.1
# Alpelisib Dose (mg)
# Alpelisib Scheduling
# Breast Cancer Subtype
# Clinical Benefit
# Endocrine Therapy
# Measurable Disease
# Off Study Reason
# Patient Display Name
# PIK3CA Pre Treatment Tumor Mutation
# PIK3CA Pre Treatment Tumor
# Best RECIST Response
# Sample Collection Time
# Tumor Sequencing Platform
# Treatment Arm
# Weeks on Study
# Age at Which Sequencing was Reported (Years)
# Patient Current Age
# Disease Free Event
# ER PCT Primary
# ER Status of the Primary
# HER2 FISH Status of Sequenced Sample
# HER2 FISH Ratio Value of Sequenced Sample
# HER2 FISH Ratio Primary
# HER2 IHC Status Primary
# HER2 IHC Status of Sequenced Sample
# HER2 IHC Score Primary
# HER2 Primary Status
# Overall HR Status of Sequenced Sample
# Invasive Carcinoma Diagnosis Age
# Time to Diagnosis Invasive Carcinoma
# Last Communication Contact
# Metastatic Disease at Last Follow-up
# Metastatic Recurrence Time
# M Stage
# NGS Sample Collection Time Period
# N Stage
# Overall HER2 Status of Sequenced Sample
# Overall Patient HER2 Status
# Overall Patient HR Status
# Overall Patient Receptor Status
# Overall Primary Tumor Grade
# Primary Nuclear Grade
# Prior Breast Primary
# Prior Local Recurrence
# PR PCT Primary
# PR Status of the Primary
# Receptor Status Primary
# Site of Sample
# Stage At Diagnosis
# Time To Death (Months)
# Tumor Sample Histology
# Tumor Tissue Origin
# T Stage
# Archer Panel
# Institute Source
# Patient Display Name.1
# Sample Display Name
# Tumor Site
# Tumor Size (cm)

# %% [markdown]
# **Limpieza de dataset de cáncer de mama  con la columna (edad)**
#
# Pregunta a contestar:
# ¿En qué edad se encuentra el mayor porcentaje de casos con cáncer de mama?

# %%
df_mama_age = df_mama['Diagnosis Age']
print(df_mama_age)
# Out:
# 0            NaN
# 1            NaN
# 2      26.000000
# 3      51.000000
# 4      40.000000
#          ...
# 477          NaN
# 478          NaN
# 479    54.500000
# 480    74.583333
# 481    65.833333
# Name: Diagnosis Age, Length: 482, dtype: float64

# %%
#Filtrado de datos Na
df_mama_age.isna().sum()
# Out:
# 298

# %%
#Se utiliza la funcion de pandas para cambiar el tipo objeto a numerico, esto
#nos facilitará el uso de funcionaes más adelante
df_mama_age = pd.to_numeric(df_mama_age, errors='coerce')

# %% [markdown]
# ##**Estimados de Locación y Variabilidad**

# %%
#Promedio de edad en cáncer de mama excepto valores NAN
promedio_age_mama = df_mama_age.mean(skipna=True)
print(promedio_age_mama)
# Out:
# 56.290905797065214

# %%
#Edad Max de cáncer de mama, exceptuando valores NAN
max_age_mama = df_mama_age.max(skipna=True)
print(max_age_mama)
# Out:
# 90.0

# %%
#Edad Min de cáncer de mama
min_age_mama = df_mama_age.min(skipna=True)
print(min_age_mama)
# Out:
# 26.0

# %%
#Rango que hay entre la edad máx y la edad min de cáncer de mama
rango_age_mama = max_age_mama - min_age_mama
print(rango_age_mama)
# Out:
# 64.0

# %%
#Media truncada

df_mama_age_nans = df_mama_age.dropna()
media_truncada = stats.trim_mean(df_mama_age_nans, 0.10)

print(media_truncada)
# Out:
# 55.68700450445946

# %%
#Estimado de variabilidad
df_mama_age.std()
# Out:
# 14.925195956536198

# %%
# Percentiles
df_mama_age.quantile(.9)
# Out:
# 77.0

# %%
#Resumen
print(f'Minimo: {df_mama_age.min()}')
print(f"P20: {df_mama_age.quantile(.1)}")
print(f'P25: {df_mama_age.quantile(.25)}')
print(f'P50: {df_mama_age.median()}')
print(f'P75: {df_mama_age.quantile(.75)}')
print(f'P90: {df_mama_age.quantile(.9)}')
print(f'Maximo: {df_mama_age.max()}')
# Out:
# Minimo: 26.0
# P20: 38.27
# P25: 44.0
# P50: 54.25
# P75: 67.0
# P90: 77.0
# Maximo: 90.0

# %%
# Rango intercuartilico
df_mama_age.quantile(0.75) - df_mama_age.quantile(0.25)
# Out:
# 23.0

# %%
#Mediana
df_mama_age.median()
# Out:
# 54.25

# %% [markdown]
# Se procede a realizar un gráfico de caja para visualizar los resultados obtenidos.

# %%
ax=sns.set(style="whitegrid")
sns.boxplot(x=df_mama_age, color= "pink")
plt.axvline(df_mama_age.mean(),c='y')

# %% [markdown]
# La gráfica boxplot nos muestra los rangos de los datos en la edad, podemos notar la edad min y máx con casos de cáncer de mama. Se nota de manera gráfica también los percentiles (bordes de la caja) y la media (línea amarilla). No cuenta con muchos valores atípicos.

# %%
sns.violinplot (x=df_mama_age, color= "grey")
# Out:
# <Axes: xlabel='Diagnosis Age'>

# %% [markdown]
# En la gráfica de violin plot podemos observar la media(punto blanco), así como los rangos intercuartilico. Se puede concluir que no se cuenta con una gran variedad de datos atípicos.

# %%
#Se imprime rango
print (rango_age_mama)
# Out:
# 64.0

# %%
#Se segmenta las edades
segmentos = pd.cut(df_mama_age, 32)
df_mama_age.groupby(segmentos).count()
# Out:
# Diagnosis Age
# (25.936, 28.0]     2
# (28.0, 30.0]       1
# (30.0, 32.0]       1
# (32.0, 34.0]       4
# (34.0, 36.0]       6
# (36.0, 38.0]       5
# (38.0, 40.0]      13
# (40.0, 42.0]       8
# (42.0, 44.0]       7
# (44.0, 46.0]       5
# (46.0, 48.0]      10
# (48.0, 50.0]       5
# (50.0, 52.0]      16
# (52.0, 54.0]       9
# (54.0, 56.0]       8
# (56.0, 58.0]       1
# (58.0, 60.0]      13
# (60.0, 62.0]      12
# (62.0, 64.0]       3
# (64.0, 66.0]       8
# (66.0, 68.0]       5
# (68.0, 70.0]       7
# (70.0, 72.0]       5
# (72.0, 74.0]       3
# (74.0, 76.0]       4
# (76.0, 78.0]       9
# (78.0, 80.0]       3
# (80.0, 82.0]       4
# (82.0, 84.0]       0
# (84.0, 86.0]       0
# (86.0, 88.0]       0
# (88.0, 90.0]       7
# Name: Diagnosis Age, dtype: int64

# %%
#Histograma
ax=sns.histplot(df_mama_age, bins=32, kde=True, color='purple', edgecolor='purple')
ax.set_title("Edad de diágnostico en pacientes con cáncer de mama")
# Out:
# Text(0.5, 1.0, 'Edad de diágnostico en pacientes con cáncer de mama')

# %%
#Skew de la gráfica
skew(df_mama_age_nans)
# Out:
# 0.31307167428028404

# %%
#Kurtosis de la gráfica
kurtosis(df_mama_age_nans)
# Out:
# -0.6291407655808059

# %% [markdown]
# El histograma representado nos muestra que tiene un comportamiento de distribución "Asimetrica a la derecha", significando que mientras más aumenta la edad, más aumentan los casos de cancer. La simetría esta a 0.31 y la kurtosis es negativa -0.62 presentando menos casos de concentración que nuestra media.

# %%
#Conteo de edad de cáncer de mama
df_conteo_mama_age=df_mama_age_nans.value_counts()
df_conteo_mama_age
# Out:
# 59.000000    11
# 52.000000     8
# 39.000000     7
# 51.000000     7
# 54.000000     7
# 62.000000     6
# 56.000000     6
# 69.000000     6
# 61.000000     6
# 40.000000     5
# 77.000000     5
# 41.000000     5
# 66.000000     5
# 47.000000     5
# 89.000000     4
# 82.000000     4
# 78.000000     4
# 43.000000     4
# 49.000000     4
# 48.000000     4
# 45.000000     3
# 90.000000     3
# 67.000000     3
# 44.000000     3
# 36.000000     3
# 38.000000     3
# 71.000000     3
# 73.000000     3
# 34.000000     3
# 75.000000     3
# 68.000000     2
# 64.000000     2
# 53.000000     2
# 65.000000     2
# 26.000000     2
# 46.000000     2
# 80.000000     2
# 58.200000     2
# 72.000000     2
# 42.000000     2
# 37.000000     2
# 74.583333     1
# 54.500000     1
# 79.000000     1
# 63.000000     1
# 48.310000     1
# 41.550000     1
# 34.060000     1
# 35.790000     1
# 50.400000     1
# 70.000000     1
# 38.900000     1
# 47.200000     1
# 35.000000     1
# 30.000000     1
# 33.000000     1
# 31.000000     1
# 55.000000     1
# 57.000000     1
# 65.833333     1
# Name: Diagnosis Age, dtype: int64

# %%
# La moda de edad con más cáncer de mama
df_mama_age_nans.mode()
# Out:
# 0    59.0
# Name: Diagnosis Age, dtype: float64

# %% [markdown]
# Pregunta responder:
#
# *  **¿En qué edad se encuentra el mayor porcentaje de casos con cáncer de
# mama?**
#
#
# Después de la limpieza de datos con una población de 298 casos, con ayuda de un histograma y tabla count, podemos observar que la edad donde se observan más casos de cancer de mama es a la edad de 59 años con 11/298 casos positivos.

# %% [markdown]
# ##**Distribuciones y exploración de variables**

# %%
#Dataset: df_mama
#Columna "Ethnicity category"
print(df_mama['Ethnicity Category'])
df_mama_ethnicity = df_mama['Ethnicity Category']
# Out:
# 0                            NaN
# 1                            NaN
# 2                        Chinese
# 3                            NaN
# 4                            NaN
#                  ...
# 477                          NaN
# 478    Black or African American
# 479                        Asian
# 480                        White
# 481                        White
# Name: Ethnicity Category, Length: 482, dtype: object

# %%
#Se cambia el formato a "minusculas" porque se repetian etnia debido al formato de letra
df_mama_ethnicity=df_mama_ethnicity.str.lower()
df_mama_ethnicity
# Out:
# 0                            NaN
# 1                            NaN
# 2                        chinese
# 3                            NaN
# 4                            NaN
#                  ...
# 477                          NaN
# 478    black or african american
# 479                        asian
# 480                        white
# 481                        white
# Name: Ethnicity Category, Length: 482, dtype: object

# %%
#Moda de la étnia con más casos
df_mama_ethnicity.mode()
# Out:
# 0    not hispanic or latino
# Name: Ethnicity Category, dtype: object

# %%
#Se saca el count de la etnia de las pacientes
df_mama_ethnicity.value_counts()
# Out:
# not hispanic or latino                    92
# non-spanish; non-hispanic                 77
# spanish  nos; hispanic nos, latino nos     6
# unknown whether spanish or not             3
# hispanic or latino                         3
# white                                      2
# chinese                                    1
# south/central america (except brazil)      1
# puerto rican                               1
# black or african american                  1
# asian                                      1
# Name: Ethnicity Category, dtype: int64

# %%
#Se unifica la etnia
df_mama_ethnicity.unique()
# Out:
# array([nan, 'chinese', 'non-spanish; non-hispanic',
#        'unknown whether spanish or not',
#        'spanish  nos; hispanic nos, latino nos',
#        'south/central america (except brazil)', 'puerto rican',
#        'not hispanic or latino', 'hispanic or latino',
#        'black or african american', 'asian', 'white'], dtype=object)

# %%
#Gráfica de barras para la etnia
counts=df_mama_ethnicity.value_counts()
ax=sns.barplot(x=counts.index, y =counts, palette="coolwarm")
ax.set(ylabel="count")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.set_title("Mujeres con cáncer de mama")
# Out:
# <ipython-input-102-5cd2e3f53943>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x=counts.index, y =counts, palette="coolwarm")
# <ipython-input-102-5cd2e3f53943>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Text(0.5, 1.0, 'Mujeres con cáncer de mama')

# %% [markdown]
# Pregunta pendiente por responder:
#
# *   **¿Existen patrones geográficos en la prevalencia de cáncer de mama?**
#
# De acuerdo a la gráfica de barras y la tabla count, podemos observar que la etnia de las mujeres donde más casos de cancer de mama es: "not hispanic or latino" presentando 92 casos de cancer.

# %%
#Se trabaja con la columna "Tipo de cáncer"
print(df_mama["Cancer Type Detailed"])
df_mama_type=df_mama["Cancer Type Detailed"]
# Out:
# 0                                    Breast
# 1                                    Breast
# 2      Benign Phyllodes Tumor of the Breast
# 3             Infiltrating Ductal Carcinoma
# 4           Ductal Carcinoma In Situ (DCIS)
#                        ...
# 477               Invasive Breast Carcinoma
# 478               Invasive Breast Carcinoma
# 479               Invasive Breast Carcinoma
# 480               Invasive Breast Carcinoma
# 481               Invasive Breast Carcinoma
# Name: Cancer Type Detailed, Length: 482, dtype: object

# %%
print(df_mama["Overall Survival Status"])
df_mama_survival=df_mama["Overall Survival Status"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 477    NaN
# 478    NaN
# 479    NaN
# 480    NaN
# 481    NaN
# Name: Overall Survival Status, Length: 482, dtype: object

# %%
#Tablas de contingencia
pd.crosstab((df_mama_survival), (df_mama_type),margins=True, margins_name="Total" )
# Out:
# Cancer Type Detailed     Breast  Breast Invasive Cancer, NOS  \
# Overall Survival Status
# 0:LIVING                      0                            2
# 1:DECEASED                    1                            0
# Total                         1                            2
#
# Cancer Type Detailed     Breast Invasive Carcinoma (NOS)  \
# Overall Survival Status
# 0:LIVING                                               3
# 1:DECEASED                                             0
# Total                                                  3
#
# Cancer Type Detailed     Breast Invasive Carcinoma, NOS  \
# Overall Survival Status
# 0:LIVING                                              0
# 1:DECEASED                                            1
# Total                                                 1
#
# Cancer Type Detailed     Breast Invasive Ductal Carcinoma  \
# Overall Survival Status
# 0:LIVING                                              140
# 1:DECEASED                                             70
# Total                                                 210
#
# Cancer Type Detailed     Breast Invasive Lobular Carcinoma  \
# Overall Survival Status
# 0:LIVING                                                23
# 1:DECEASED                                              11
# Total                                                   34
#
# Cancer Type Detailed     Breast Invasive Mixed Mucinous Carcinoma  \
# Overall Survival Status
# 0:LIVING                                                        1
# 1:DECEASED                                                      0
# Total                                                           1
#
# Cancer Type Detailed     Breast Mixed Ductal and Lobular Carcinoma  \
# Overall Survival Status
# 0:LIVING                                                        14
# 1:DECEASED                                                       3
# Total                                                           17
#
# Cancer Type Detailed     Invasive Breast Carcinoma  Metaplastic Breast Cancer  \
# Overall Survival Status
# 0:LIVING                                        44                          2
# 1:DECEASED                                       3                          0
# Total                                           47                          2
#
# Cancer Type Detailed     Total
# Overall Survival Status
# 0:LIVING                   229
# 1:DECEASED                  89
# Total                      318

# %% [markdown]
# Con esta tabla de contigencia podemos observar cada tipo de cancer de mama respecto a su estado del paciente (vivo, muerto).

# %%
#Count de tipos de cáncer
df_mama_type.value_counts()
# Out:
# Breast Invasive Ductal Carcinoma             270
# Invasive Breast Carcinoma                    109
# Breast Invasive Lobular Carcinoma             54
# Breast Mixed Ductal and Lobular Carcinoma     23
# Breast Invasive Carcinoma, NOS                 7
# Breast                                         3
# Infiltrating Ductal Carcinoma                  3
# Breast Invasive Cancer, NOS                    3
# Breast Invasive Carcinoma (NOS)                3
# Metaplastic Breast Cancer                      2
# Invasive Breast Cancer                         2
# Benign Phyllodes Tumor of the Breast           1
# Ductal Carcinoma In Situ (DCIS)                1
# Breast Invasive Mixed Mucinous Carcinoma       1
# Name: Cancer Type Detailed, dtype: int64

# %%
#Gráfica de barras para "tipo de cancer"
counts=df_mama_type.value_counts()
ax=sns.barplot(x=counts.index, y =counts, palette="magma")
ax.set(ylabel="count")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.set_title("Tipos de cáncer de mama")
# Out:
# <ipython-input-107-89cbdbb7078d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x=counts.index, y =counts, palette="magma")
# <ipython-input-107-89cbdbb7078d>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Text(0.5, 1.0, 'Tipos de cáncer de mama')

# %% [markdown]
# *  **¿Cuál es el “tipo de cáncer” de mama  con más casos?**
#
# Podemos observar de acuerdo a la función "Count" que el cancér con más casos es el "Breast Invasive Ductal Carcinoma" con 270 casos totales, y gracias a la tabla de contigencia podemos notar que de esos 270 de ese tipo de cáncer solo 140 pacientes siguen con vida.
#
# Pregunta:
#
# * **¿Cuál es la frecuencia de supervivencia entre las pacientes?**
#
# Gracias a la tabla de contigencia podemos observar que el total de datos disponibles con "tipo de cancer" y "superviviencia" es que de las 318 pacientes, 229 siguen vivas y desafortunamente 89 han perdido la vida contra la lucha de esta enfermedad.

# %%
#Se manda a llamar df
brca1_mama_mutation.head()
# Out:
#                                                                                  Sample ID  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                                    MBC_47
# The Metastatic Breast Cancer Project (Archived,...  MBC-MBCProject_zatdFvhp-Tumor-SM-GQAAR
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-BH-A0WA-01
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-AN-A0XU-01
# Breast Invasive Carcinoma (TCGA, Nature 2012)                              TCGA-AR-A0U4-01
#
#                                                       Cancer Type  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)    Breast Cancer
# The Metastatic Breast Cancer Project (Archived,...  Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Breast Cancer
#
#                                                            Cancer Type Detailed  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)      Invasive Breast Carcinoma
# The Metastatic Breast Cancer Project (Archived,...  Breast Invasive Cancer, NOS
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
# Breast Invasive Carcinoma (TCGA, Nature 2012)         Invasive Breast Carcinoma
#
#                                                    Protein Change  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)       M1728Kfs*3
# The Metastatic Breast Cancer Project (Archived,...   X1823_splice
# Breast Invasive Carcinoma (TCGA, Nature 2012)        X1559_splice
# Breast Invasive Carcinoma (TCGA, Nature 2012)              G1788V
# Breast Invasive Carcinoma (TCGA, Nature 2012)         N1121Kfs*12
#
#                                                    Annotation OncoKb  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)    Likely Oncogenic
# The Metastatic Breast Cancer Project (Archived,...  Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
# Breast Invasive Carcinoma (TCGA, Nature 2012)       Likely Oncogenic
#
#                                                    CancerHotspot  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)              no
# The Metastatic Breast Cancer Project (Archived,...            no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 no
#
#                                                    MutationAssesor Impact  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      medium
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                     SIFT Impact  sift_score  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)            NaN         NaN
# The Metastatic Breast Cancer Project (Archived,...          NaN         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)               NaN         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)       deleterious         0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)               NaN         NaN
#
#                                                    Polyphen-2 Impact  ...  \
# Study of Origin                                                       ...
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                 NaN  ...
# The Metastatic Breast Cancer Project (Archived,...               NaN  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                 benign  ...
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN  ...
#
#                                                     Time To Death (Months)  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                       NaN
# The Metastatic Breast Cancer Project (Archived,...                     NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                          NaN
#
#                                                    Tumor Sample Histology  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                     Tumor Tissue Origin  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                    NaN
# The Metastatic Breast Cancer Project (Archived,...                  NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                       NaN
#
#                                                    T Stage  Archer Panel  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)       NaN           NaN
# The Metastatic Breast Cancer Project (Archived,...     NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)          NaN           NaN
#
#                                                    Institute Source  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                NaN
# The Metastatic Breast Cancer Project (Archived,...              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
#
#                                                    Patient Display Name.1  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                      NaN
# The Metastatic Breast Cancer Project (Archived,...                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                         NaN
#
#                                                    Sample Display Name  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                   NaN
# The Metastatic Breast Cancer Project (Archived,...                 NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                      NaN
#
#                                                     Tumor Site  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)           NaN
# The Metastatic Breast Cancer Project (Archived,...         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
#
#                                                     Tumor Size (cm)
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                NaN
# The Metastatic Breast Cancer Project (Archived,...              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                   NaN
#
# [5 rows x 586 columns]

# %% [markdown]
# ##**Correlación**

# %%
#Seleccionamos nombre de columnas para el análisis de correlación
columnas_seleccionadas = [
    "sift_score",
    "polyphen_2_score",
    "diagnosis_age",
    "status_pacient"]

# %%
#Se crea el datadf_brca1_mama_mutationframe
df_brca1_mama_mutation = brca1_mama_mutation[columnas_seleccionadas]
df_brca1_mama_mutation
# Out:
#                                                     sift_score  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)           NaN
# The Metastatic Breast Cancer Project (Archived,...         NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)             0.00
# Breast Invasive Carcinoma (TCGA, Nature 2012)              NaN
# ...                                                        ...
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)          NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)          NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)          NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.18
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.00
#
#                                                     polyphen_2_score  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)                 NaN
# The Metastatic Breast Cancer Project (Archived,...               NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.022
# Breast Invasive Carcinoma (TCGA, Nature 2012)                    NaN
# ...                                                              ...
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)                NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)                NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)                NaN
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.549
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.038
#
#                                                     diagnosis_age  \
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)              NaN
# The Metastatic Breast Cancer Project (Archived,...            NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                82.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                54.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                54.0
# ...                                                           ...
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            49.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            51.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            52.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            59.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            41.0
#
#                                                     status_pacient
# Study of Origin
# Metastatic Breast Cancer (INSERM, PLoS Med 2016)               NaN
# The Metastatic Breast Cancer Project (Archived,...             NaN
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# ...                                                            ...
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
#
# [225 rows x 4 columns]

# %%
#Correlación
df_brca1_mama_mutation.corr()
# Out:
#                   sift_score  polyphen_2_score  diagnosis_age  status_pacient
# sift_score          1.000000         -0.319986       0.016820        0.194766
# polyphen_2_score   -0.319986          1.000000       0.058174       -0.004434
# diagnosis_age       0.016820          0.058174       1.000000        0.188905
# status_pacient      0.194766         -0.004434       0.188905        1.000000

# %%
#Heatmap
plt.figure(figsize=(8,6))
ax= sns.heatmap(df_brca1_mama_mutation.corr(),vmin=-1,vmax=1,annot=True, cmap= "twilight")

# %%
#Eliminando NA para obtener el scatterplot

columnas_interes = ["sift_score", "polyphen_2_score", "diagnosis_age", "status_pacient"]
brca1_mama_sin_nan = brca1_mama_mutation.dropna(subset=columnas_interes)
print(brca1_mama_sin_nan[columnas_interes])
# Out:
#                                                     sift_score  \
# Study of Origin
# Breast Invasive Carcinoma (TCGA, Nature 2012)             0.00
# Breast Invasive Carcinoma (TCGA, Nature 2012)             0.00
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.00
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.00
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.00
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.00
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.00
# Breast Invasive Carcinoma (TCGA, Nature 2012)             0.00
# Breast Invasive Carcinoma (TCGA, Nature 2012)             0.04
# MAPK on resistance to anti-HER2 therapy for bre...        0.17
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.05
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.04
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.18
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.00
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.01
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.01
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)         0.00
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.05
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.04
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.18
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.01
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.00
# Breast Invasive Carcinoma (TCGA, Cell 2015)               0.00
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.05
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.04
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.18
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)         0.00
#
#                                                     polyphen_2_score  \
# Study of Origin
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.022
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.125
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.022
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.125
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.022
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.125
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.022
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.886
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.533
# MAPK on resistance to anti-HER2 therapy for bre...             0.144
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.844
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.533
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.549
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.038
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.540
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.770
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.747
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.844
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.533
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.549
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.770
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.770
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.070
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.844
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.533
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.549
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.038
#
#                                                     diagnosis_age  \
# Study of Origin
# Breast Invasive Carcinoma (TCGA, Nature 2012)                54.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                71.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            54.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            71.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  54.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  71.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            54.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                80.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                43.0
# MAPK on resistance to anti-HER2 therapy for bre...           58.2
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            40.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            43.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            59.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            41.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            68.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            69.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)            45.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  40.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  43.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  59.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  69.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  56.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                  46.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            40.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            43.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            59.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)            41.0
#
#                                                     status_pacient
# Study of Origin
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# Breast Invasive Carcinoma (TCGA, Nature 2012)                  0.0
# MAPK on resistance to anti-HER2 therapy for bre...             1.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              1.0
# Breast Invasive Carcinoma (TCGA, PanCancer Atlas)              0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    1.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Cell 2015)                    0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0
# Breast Invasive Carcinoma (TCGA, Firehose Legacy)              0.0

# %%
#'sift_score' y 'polyphen_2_score' son las columnas de interés (sin NaN)

sns.scatterplot(x='sift_score', y='polyphen_2_score', data=brca1_mama_sin_nan)
# Out:
# <Axes: xlabel='sift_score', ylabel='polyphen_2_score'>

# %%
#Correlación entre "Sift_score" y "Polypen_score"
brca1_mama_sin_nan ['sift_score'].corr(brca1_mama_sin_nan['polyphen_2_score'])
# Out:
# 0.20067430843229603

# %% [markdown]
# La correlación entre estás dos variables es de 0.20

# %% [markdown]
# ##**Muestreo Aleatorio y Bootstrapping**

# %%
#Obtener muestra aleatoria de BRCA1
brca1_sample = brca1_mama_sin_nan.sample(n=15, replace = False)

# %%
#La muestra con Bootstrap se realizará con el dato de sift score (este dato nos
#ayuda a medir qué tan dañina es la mutación)

sift_score = brca1_mama_sin_nan['sift_score']
means = []

#Elegimos el valor B para cantidad de muestras
for i in range (200):
  sample = sift_score.sample(n=20,  replace=True)
  #Agregamos la media aritmética
  means.append(sample.mean())

# %%
#Creamos una serie con las medias aritméticas y gráficamos
serie_means = pd.Series(means)
sns.displot(data=serie_means, kde=False).set(title="Media artimética de Protein Change")
sns.set_style("ticks")

# %% [markdown]
# ##**Errores e Intervalos de confianza**

# %%
#A partir de lo realizado con bootstrap, obtenemos la variación estandar para visualizar la dispersión de nuestros datos

print(f'Error estandar: {serie_means.std()}')
# Out:
# Error estandar: 0.013618388165680834

# %%
#Se genera los cuantiles para nuestros intervalos de confianza

limite_inferior = serie_means.quantile(0.025)

limite_superior = serie_means.quantile(0.975)

media = serie_means.mean()

print(f'Intervalo de 95% de confianza de la media: {limite_inferior} < {media} < {limite_superior}')
# Out:
# Intervalo de 95% de confianza de la media: 0.01495 < 0.0382925 < 0.07051249999999999

# %%
sns.displot(x=serie_means, kde=False).set(title="Media artimética con Intervalos de Confianza")
sns.set_style("ticks")
plt.axvline(limite_inferior,c='y')
plt.axvline(limite_superior,c='y')

# %% [markdown]
# Observando esta gráfica podemos definir que al elegir una muestra aleatoria de nuestro conjunto de datos es muy probable que se seleccione un número dentro de los intervalos de confianza.

# %% [markdown]
# ##**Regresión lineal**

# %%
#Modelo
lr= LinearRegression()

# %%
x = brca1_mama_sin_nan['sift_score'].to_frame()
y = brca1_mama_sin_nan['polyphen_2_score']
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(brca1_mama_sin_nan['sift_score'].to_frame())

# %%
#Scatterplot regresión Lineal

sns.scatterplot(x=brca1_mama_sin_nan['sift_score'], y=y, c='orange').set(title="Scatterplot regresión Lineal")

#Las siguientes dos líneas representan la predicción, una en formato de línea y
#la siguiente marcando los puntos
sns.lineplot(x=brca1_mama_sin_nan['sift_score'], y=y_predict, c='pink')
sns.scatterplot(x=brca1_mama_sin_nan['sift_score'], y=y_predict, c='pink')
# Out:
# <Axes: title={'center': 'Scatterplot regresión Lineal'}, xlabel='sift_score', ylabel='polyphen_2_score'>

# %%
#Evaluación de modelo
lr.fit(x, y)
lr.score(x,y)
# Out:
# 0.04027017806477995

# %% [markdown]
# **Conclusión de regresión lineal**
#
# Debido al score mostrado en la evaluación del modelo *(0.04027017806477995
# )*, hemos definido que los datos utilizados para realizar la regresión no son suficientes para poder generar un buen modelo de predicción.

# %% [markdown]
# ##**Validación cruzada**

# %%
#Utilizaremos la información de regresión lineal para hacer la validación cruzada
scores = cross_validate(lr, x, y, scoring='r2')
scores
# Out:
# {'fit_time': array([0.02708411, 0.01426363, 0.01455259, 0.00353241, 0.00367284]),
#  'score_time': array([0.01345634, 0.00294065, 0.00722408, 0.01518559, 0.00932455]),
#  'test_score': array([-78.50781083,  -0.34676601,  -0.28994309,  -6.71848856,
#           0.1173245 ])}

# %%
print(f'Score del modelo: {scores["test_score"].mean():.3f} +/- {scores["test_score"].std():.3f}')
# Out:
# Score del modelo: -17.149 +/- 30.784

# %% [markdown]
# Contrastando la media del score del modelo contra la std de este, se obtiene la evaluación anterior. En base a esto se determina que es necesario tener un modelo más robusto para mejorar el score de este mismo.

# %% [markdown]
# ##**Pruebas A/B**

# %%
brca1_mama_ab = pd.read_csv('https://raw.githubusercontent.com/PaolaSantiago00/C-ncer-de-mama/main/BRCA1_mama%20(separado)%20NUEVO%20-%20BRCA1_mama%20(separado)%20NUEVO%20(1).csv')
brca1_mama_ab
# Out:
#                                        Study of Origin  \
# 0     Metastatic Breast Cancer (INSERM, PLoS Med 2016)
# 1    The Metastatic Breast Cancer Project (Archived...
# 2        Breast Invasive Carcinoma (TCGA, Nature 2012)
# 3        Breast Invasive Carcinoma (TCGA, Nature 2012)
# 4        Breast Invasive Carcinoma (TCGA, Nature 2012)
# ..                                                 ...
# 220  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 221  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 222  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 223  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 224  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
#
#                                   Sample ID    Cancer Type  \
# 0                                    MBC_47  Breast Cancer
# 1    MBC-MBCProject_zatdFvhp-Tumor-SM-GQAAR  Breast Cancer
# 2                           TCGA-BH-A0WA-01  Breast Cancer
# 3                           TCGA-AN-A0XU-01  Breast Cancer
# 4                           TCGA-AR-A0U4-01  Breast Cancer
# ..                                      ...            ...
# 220                         TCGA-LL-A5YP-01  Breast Cancer
# 221                         TCGA-AO-A1KR-01  Breast Cancer
# 222                         TCGA-A1-A0SI-01  Breast Cancer
# 223                         TCGA-EW-A2FR-01  Breast Cancer
# 224                         TCGA-PE-A5DE-01  Breast Cancer
#
#                   Cancer Type Detailed Protein Change Annotation OncoKb  \
# 0            Invasive Breast Carcinoma     M1728Kfs*3  Likely Oncogenic
# 1          Breast Invasive Cancer, NOS   X1823_splice  Likely Oncogenic
# 2            Invasive Breast Carcinoma   X1559_splice  Likely Oncogenic
# 3            Invasive Breast Carcinoma         G1788V  Likely Oncogenic
# 4            Invasive Breast Carcinoma    N1121Kfs*12  Likely Oncogenic
# ..                                 ...            ...               ...
# 220   Breast Invasive Ductal Carcinoma           D96H           Unknown
# 221   Breast Invasive Ductal Carcinoma        C644del           Unknown
# 222   Breast Invasive Ductal Carcinoma            E9Q           Unknown
# 223   Breast Invasive Ductal Carcinoma          D366N           Unknown
# 224  Breast Invasive Lobular Carcinoma         E1419K           Unknown
#
#     CancerHotspot MutationAssesor Impact  SIFT Impact  sift_score  ...  \
# 0              no                    NaN          NaN         NaN  ...
# 1              no                    NaN          NaN         NaN  ...
# 2              no                    NaN          NaN         NaN  ...
# 3              no                 medium  deleterious        0.00  ...
# 4              no                    NaN          NaN         NaN  ...
# ..            ...                    ...          ...         ...  ...
# 220            no                 medium          NaN         NaN  ...
# 221            no                    NaN          NaN         NaN  ...
# 222            no                    low          NaN         NaN  ...
# 223            no                 medium    tolerated        0.18  ...
# 224            no                 medium  deleterious        0.00  ...
#
#     Time To Death (Months)  Tumor Sample Histology Tumor Tissue Origin  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                 NaN
# 2                      NaN                     NaN                 NaN
# 3                      NaN                     NaN                 NaN
# 4                      NaN                     NaN                 NaN
# ..                     ...                     ...                 ...
# 220                    NaN                     NaN                 NaN
# 221                    NaN                     NaN                 NaN
# 222                    NaN                     NaN                 NaN
# 223                    NaN                     NaN                 NaN
# 224                    NaN                     NaN                 NaN
#
#     T Stage  Archer Panel Institute Source Patient Display Name.1  \
# 0       NaN           NaN              NaN                    NaN
# 1       NaN           NaN              NaN                    NaN
# 2       NaN           NaN              NaN                    NaN
# 3       NaN           NaN              NaN                    NaN
# 4       NaN           NaN              NaN                    NaN
# ..      ...           ...              ...                    ...
# 220     NaN           NaN              NaN                    NaN
# 221     NaN           NaN              NaN                    NaN
# 222     NaN           NaN              NaN                    NaN
# 223     NaN           NaN              NaN                    NaN
# 224     NaN           NaN              NaN                    NaN
#
#     Sample Display Name  Tumor Site  Tumor Size (cm)
# 0                   NaN         NaN              NaN
# 1                   NaN         NaN              NaN
# 2                   NaN         NaN              NaN
# 3                   NaN         NaN              NaN
# 4                   NaN         NaN              NaN
# ..                  ...         ...              ...
# 220                 NaN         NaN              NaN
# 221                 NaN         NaN              NaN
# 222                 NaN         NaN              NaN
# 223                 NaN         NaN              NaN
# 224                 NaN         NaN              NaN
#
# [225 rows x 588 columns]

# %%
# Obtener e imprimir el nombre de todas las columnas
print("Nombres de las columnas:")
for nombre_columna in brca1_mama_ab.columns:
    print(nombre_columna)

# %%
count_ab = brca1_mama_ab.groupby('Annotation OncoKb')[['LIVING', 'DECEASED']].sum()
count_ab
# Out:
#                    LIVING  DECEASED
# Annotation OncoKb
# Inconclusive          5.0       1.0
# Likely Neutral        2.0       1.0
# Likely Oncogenic     52.0      10.0
# Oncogenic             5.0       1.0
# Unknown              49.0      20.0

# %%
count_ab['success rate'] = count_ab['LIVING'] / (count_ab['LIVING'] + count_ab['DECEASED'])
count_ab
# Out:
#                    LIVING  DECEASED  success rate
# Annotation OncoKb
# Inconclusive          5.0       1.0      0.833333
# Likely Neutral        2.0       1.0      0.666667
# Likely Oncogenic     52.0      10.0      0.838710
# Oncogenic             5.0       1.0      0.833333
# Unknown              49.0      20.0      0.710145

# %%
diferencia_proporcion = 1 - (count_ab.loc['Oncogenic']['success rate']/count_ab.loc['Likely Oncogenic']['success rate'])
diferencia_porcentaje = diferencia_proporcion *100
print (f"El test 'Likely Oncogenic' fue {diferencia_porcentaje:.2f}% más agresivo que 'Oncogenic'")
# Out:
# El test 'Likely Oncogenic' fue 0.64% más agresivo que 'Oncogenic'

# %%
all_measurements = brca1_mama_ab[['LIVING', 'DECEASED']]
value_counts = brca1_mama_ab['Annotation OncoKb'].value_counts()

value_counts
# Out:
# Unknown             110
# Likely Oncogenic     93
# Oncogenic             9
# Inconclusive          7
# Likely Neutral        6
# Name: Annotation OncoKb, dtype: int64

# %%
#Aplicación de algoritmo de permutación

conv_a = []
no_conv_a = []
conv_b = []
no_conv_b = []

for i in range(225):
  likely_onc = brca1_mama_ab.sample(value_counts.loc['Likely Oncogenic'], replace = False)
  conv_a.append(likely_onc['LIVING'].sum())
  no_conv_a.append(likely_onc['DECEASED'].sum())
  unknown_onco = brca1_mama_ab.sample(value_counts.loc['Oncogenic'], replace = False)
  conv_b.append(likely_onc['LIVING'].sum())
  no_conv_b.append(likely_onc['DECEASED'].sum())

# %%
#Nuevo data frame con permutaciones

perm_result = pd.DataFrame({
    'conv_a':conv_a,
    'no_conv_a':no_conv_a,
    'conv_b':conv_b,
    'no_conv_b':no_conv_b
})

perm_result
# Out:
#      conv_a  no_conv_a  conv_b  no_conv_b
# 0      49.0       18.0    49.0       18.0
# 1      46.0       17.0    46.0       17.0
# 2      41.0       15.0    41.0       15.0
# 3      52.0       10.0    52.0       10.0
# 4      47.0       11.0    47.0       11.0
# ..      ...        ...     ...        ...
# 220    43.0       14.0    43.0       14.0
# 221    47.0       10.0    47.0       10.0
# 222    50.0        9.0    50.0        9.0
# 223    47.0       11.0    47.0       11.0
# 224    56.0        8.0    56.0        8.0
#
# [225 rows x 4 columns]

# %%
#Asignación de nuevas columnas

perm_result['a_conv_rate'] = perm_result['conv_a'] / (perm_result['conv_a'] + perm_result['no_conv_a'])

perm_result['b_conv_rate'] = perm_result['conv_b'] / (perm_result['conv_b'] + perm_result['no_conv_b'])

# %%
#Obtenemos diferencias de relacion AB permutados
perm_result['diff'] = 1 - (perm_result['b_conv_rate'] / perm_result['a_conv_rate'])

perm_result
# Out:
#      conv_a  no_conv_a  conv_b  no_conv_b  a_conv_rate  b_conv_rate  diff
# 0      49.0       18.0    49.0       18.0     0.731343     0.731343   0.0
# 1      46.0       17.0    46.0       17.0     0.730159     0.730159   0.0
# 2      41.0       15.0    41.0       15.0     0.732143     0.732143   0.0
# 3      52.0       10.0    52.0       10.0     0.838710     0.838710   0.0
# 4      47.0       11.0    47.0       11.0     0.810345     0.810345   0.0
# ..      ...        ...     ...        ...          ...          ...   ...
# 220    43.0       14.0    43.0       14.0     0.754386     0.754386   0.0
# 221    47.0       10.0    47.0       10.0     0.824561     0.824561   0.0
# 222    50.0        9.0    50.0        9.0     0.847458     0.847458   0.0
# 223    47.0       11.0    47.0       11.0     0.810345     0.810345   0.0
# 224    56.0        8.0    56.0        8.0     0.875000     0.875000   0.0
#
# [225 rows x 7 columns]

# %%
perm_result['porcentaje'] = count_ab['LIVING']/ (count_ab['LIVING']+count_ab ['DECEASED'])
perm_result
# Out:
#      conv_a  no_conv_a  conv_b  no_conv_b  a_conv_rate  b_conv_rate  diff  \
# 0      49.0       18.0    49.0       18.0     0.731343     0.731343   0.0
# 1      46.0       17.0    46.0       17.0     0.730159     0.730159   0.0
# 2      41.0       15.0    41.0       15.0     0.732143     0.732143   0.0
# 3      52.0       10.0    52.0       10.0     0.838710     0.838710   0.0
# 4      47.0       11.0    47.0       11.0     0.810345     0.810345   0.0
# ..      ...        ...     ...        ...          ...          ...   ...
# 220    43.0       14.0    43.0       14.0     0.754386     0.754386   0.0
# 221    47.0       10.0    47.0       10.0     0.824561     0.824561   0.0
# 222    50.0        9.0    50.0        9.0     0.847458     0.847458   0.0
# 223    47.0       11.0    47.0       11.0     0.810345     0.810345   0.0
# 224    56.0        8.0    56.0        8.0     0.875000     0.875000   0.0
#
#      porcentaje
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 220         NaN
# 221         NaN
# 222         NaN
# 223         NaN
# 224         NaN
#
# [225 rows x 8 columns]

# %%
sns.distplot(perm_result['diff'], kde=False, norm_hist=False)
plt.axvline(diferencia_proporcion)
# Out:
# <ipython-input-182-1eb28d80bde3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(perm_result['diff'], kde=False, norm_hist=False)

# %% [markdown]
# En la gráfica solamente se gráfica una barra sobre el valor de 0, ya que con las pruebas A/B se demustra que no hay una diferencia, debido a que esta es mínima al visualizarse.

# %%
valor_alfa=(perm_result['diff'] >= diferencia_proporcion).sum() / perm_result.shape[0]
print(f"El valor alfa resultante es de {valor_alfa}")
# Out:
# El valor alfa resultante es de 0.0

# %% [markdown]
# ##**Expresiones Regulares y NLTK**

# %%
import re
import nltk

# %%
#Agrupación de datos
group_by_protein_change = brca1_mama_mutation.groupby('Protein Change')['Annotation OncoKb'].max()

#Limpieza de datos
group_by_protein_change = group_by_protein_change.str.lower()
group_by_protein_change = group_by_protein_change.str.strip()

print(group_by_protein_change)
# Out:
# Protein Change
# A1708V                     inconclusive
# BRCA1-ERICH5 Fusion    likely oncogenic
# BRCA1-NGFR Fusion      likely oncogenic
# BRCA1-USP25 Fusion     likely oncogenic
# C197Y                           unknown
#                              ...
# X198_splice            likely oncogenic
# X27_splice             likely oncogenic
# Y1127H                          unknown
# Y1463*                 likely oncogenic
# Y655Vfs*18             likely oncogenic
# Name: Annotation OncoKb, Length: 160, dtype: object

# %%
#Agrupación por proteínas en Likely Oncogenic
group_by_protein_change[group_by_protein_change.str.contains('Likely Oncogenic',case = False)]
# Out:
# Protein Change
# BRCA1-ERICH5 Fusion    likely oncogenic
# BRCA1-NGFR Fusion      likely oncogenic
# BRCA1-USP25 Fusion     likely oncogenic
# C360*                  likely oncogenic
# C61G                   likely oncogenic
#                              ...
# X1823_splice           likely oncogenic
# X198_splice            likely oncogenic
# X27_splice             likely oncogenic
# Y1463*                 likely oncogenic
# Y655Vfs*18             likely oncogenic
# Name: Annotation OncoKb, Length: 64, dtype: object

# %% [markdown]
# Librería NLTK aplicación

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Vector de relación de palabras
tokenized = group_by_protein_change.apply(nltk.word_tokenize)

all_words = tokenized.sum()
text = nltk.Text(all_words)
text
# Out:
# <Text: inconclusive likely oncogenic likely oncogenic likely oncogenic unknown...>

# %%
text.concordance('oncogenic', lines=20)
# Out:
# Displaying 20 of 71 matches:
# inconclusive likely oncogenic likely oncogenic likely oncogenic
# conclusive likely oncogenic likely oncogenic likely oncogenic unknown unknown l
#  oncogenic likely oncogenic likely oncogenic unknown unknown likely oncogenic l
# y oncogenic unknown unknown likely oncogenic likely oncogenic unknown likely on
# wn unknown likely oncogenic likely oncogenic unknown likely oncogenic unknown u
# ic likely oncogenic unknown likely oncogenic unknown unknown inconclusive unkno
# own unknown unknown unknown likely oncogenic likely neutral likely oncogenic un
# ly oncogenic likely neutral likely oncogenic unknown unknown likely oncogenic l
# y oncogenic unknown unknown likely oncogenic likely oncogenic unknown likely on
# wn unknown likely oncogenic likely oncogenic unknown likely oncogenic likely on
# ic likely oncogenic unknown likely oncogenic likely oncogenic unknown likely ne
# ic unknown likely oncogenic likely oncogenic unknown likely neutral unknown lik
# nown likely neutral unknown likely oncogenic unknown inconclusive likely oncoge
# ogenic unknown inconclusive likely oncogenic oncogenic oncogenic oncogenic onco
# nown inconclusive likely oncogenic oncogenic oncogenic oncogenic oncogenic onco
# clusive likely oncogenic oncogenic oncogenic oncogenic oncogenic oncogenic like
# kely oncogenic oncogenic oncogenic oncogenic oncogenic oncogenic likely oncogen
# enic oncogenic oncogenic oncogenic oncogenic oncogenic likely oncogenic unknown
# enic oncogenic oncogenic oncogenic oncogenic likely oncogenic unknown unknown u
# cogenic oncogenic oncogenic likely oncogenic unknown unknown unknown unknown li

# %%
text.concordance('unknown', lines=20)
# Out:
# Displaying 20 of 80 matches:
# c likely oncogenic likely oncogenic unknown unknown likely oncogenic likely onc
#  oncogenic likely oncogenic unknown unknown likely oncogenic likely oncogenic u
# n likely oncogenic likely oncogenic unknown likely oncogenic unknown unknown in
#  oncogenic unknown likely oncogenic unknown unknown inconclusive unknown inconc
# ic unknown likely oncogenic unknown unknown inconclusive unknown inconclusive u
# ogenic unknown unknown inconclusive unknown inconclusive unknown unknown unknow
# n inconclusive unknown inconclusive unknown unknown unknown unknown likely onco
# lusive unknown inconclusive unknown unknown unknown unknown likely oncogenic li
# nknown inconclusive unknown unknown unknown unknown likely oncogenic likely neu
# nconclusive unknown unknown unknown unknown likely oncogenic likely neutral lik
# nic likely neutral likely oncogenic unknown unknown likely oncogenic likely onc
# ly neutral likely oncogenic unknown unknown likely oncogenic likely oncogenic u
# n likely oncogenic likely oncogenic unknown likely oncogenic likely oncogenic u
# n likely oncogenic likely oncogenic unknown likely neutral unknown likely oncog
# ly oncogenic unknown likely neutral unknown likely oncogenic unknown inconclusi
# ly neutral unknown likely oncogenic unknown inconclusive likely oncogenic oncog
# ncogenic oncogenic likely oncogenic unknown unknown unknown unknown likely onco
#  oncogenic likely oncogenic unknown unknown unknown unknown likely oncogenic li
# ic likely oncogenic unknown unknown unknown unknown likely oncogenic likely onc
# y oncogenic unknown unknown unknown unknown likely oncogenic likely oncogenic l

# %%
from wordcloud import WordCloud

wordcloud=WordCloud(max_font_size=100,width=800, height=400, background_color='beige', colormap='RdPu').generate(
    ' '.join(group_by_protein_change))

plt.figure(figsize=(15,15))
plt.title('Word cloud Cancer types')
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
freq_dist_onco= nltk.FreqDist(group_by_protein_change)
plt.title("Frecuencia de tipos de cáncer")
freq_dist_onco.plot(50, cumulative=True)
# Out:
# <Axes: title={'center': 'Frecuencia de tipos de cáncer'}, xlabel='Samples', ylabel='Cumulative Counts'>

# %% [markdown]
# En las gráficas anteriores se han graficado las frequencias de tipos de cáncer en las muestras tomadas del DF.

# %% [markdown]
# ##**Machine Learning**

# %%
protein_change = pd.read_csv('https://raw.githubusercontent.com/PaolaSantiago00/C-ncer-de-mama/main/aminoacidos.csv')

# Crear una nueva columna sin letras para protein change
protein_change['protein_change_numbers_only'] = protein_change['aminoacid'].str.replace(r'\D', '', regex=True)

# Mostrar el DataFrame resultante
print(protein_change)
# Out:
#                                        Study of Origin  \
# 0     Metastatic Breast Cancer (INSERM, PLoS Med 2016)
# 1    The Metastatic Breast Cancer Project (Archived...
# 2        Breast Invasive Carcinoma (TCGA, Nature 2012)
# 3        Breast Invasive Carcinoma (TCGA, Nature 2012)
# 4        Breast Invasive Carcinoma (TCGA, Nature 2012)
# ..                                                 ...
# 220  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 221  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 222  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 223  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
# 224  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
#
#                                   Sample ID    Cancer Type  \
# 0                                    MBC_47  Breast Cancer
# 1    MBC-MBCProject_zatdFvhp-Tumor-SM-GQAAR  Breast Cancer
# 2                           TCGA-BH-A0WA-01  Breast Cancer
# 3                           TCGA-AN-A0XU-01  Breast Cancer
# 4                           TCGA-AR-A0U4-01  Breast Cancer
# ..                                      ...            ...
# 220                         TCGA-LL-A5YP-01  Breast Cancer
# 221                         TCGA-AO-A1KR-01  Breast Cancer
# 222                         TCGA-A1-A0SI-01  Breast Cancer
# 223                         TCGA-EW-A2FR-01  Breast Cancer
# 224                         TCGA-PE-A5DE-01  Breast Cancer
#
#                   Cancer Type Detailed protein_change     aminoacid  \
# 0            Invasive Breast Carcinoma     M1728Kfs*3      M1728Kfs
# 1          Breast Invasive Cancer, NOS   X1823_splice  X1823_splice
# 2            Invasive Breast Carcinoma   X1559_splice  X1559_splice
# 3            Invasive Breast Carcinoma         G1788V        G1788V
# 4            Invasive Breast Carcinoma    N1121Kfs*12      N1121Kfs
# ..                                 ...            ...           ...
# 220   Breast Invasive Ductal Carcinoma           D96H          D96H
# 221   Breast Invasive Ductal Carcinoma        C644del       C644del
# 222   Breast Invasive Ductal Carcinoma            E9Q           E9Q
# 223   Breast Invasive Ductal Carcinoma          D366N         D366N
# 224  Breast Invasive Lobular Carcinoma         E1419K        E1419K
#
#     Annotation OncoKb CancerHotspot MutationAssesor Impact  SIFT Impact  ...  \
# 0    Likely Oncogenic            no                    NaN          NaN  ...
# 1    Likely Oncogenic            no                    NaN          NaN  ...
# 2    Likely Oncogenic            no                    NaN          NaN  ...
# 3    Likely Oncogenic            no                 medium  deleterious  ...
# 4    Likely Oncogenic            no                    NaN          NaN  ...
# ..                ...           ...                    ...          ...  ...
# 220           Unknown            no                 medium          NaN  ...
# 221           Unknown            no                    NaN          NaN  ...
# 222           Unknown            no                    low          NaN  ...
# 223           Unknown            no                 medium    tolerated  ...
# 224           Unknown            no                 medium  deleterious  ...
#
#      Tumor Sample Histology Tumor Tissue Origin  T Stage Archer Panel  \
# 0                       NaN                 NaN      NaN          NaN
# 1                       NaN                 NaN      NaN          NaN
# 2                       NaN                 NaN      NaN          NaN
# 3                       NaN                 NaN      NaN          NaN
# 4                       NaN                 NaN      NaN          NaN
# ..                      ...                 ...      ...          ...
# 220                     NaN                 NaN      NaN          NaN
# 221                     NaN                 NaN      NaN          NaN
# 222                     NaN                 NaN      NaN          NaN
# 223                     NaN                 NaN      NaN          NaN
# 224                     NaN                 NaN      NaN          NaN
#
#      Institute Source Patient Display Name.1  Sample Display Name Tumor Site  \
# 0                 NaN                    NaN                  NaN        NaN
# 1                 NaN                    NaN                  NaN        NaN
# 2                 NaN                    NaN                  NaN        NaN
# 3                 NaN                    NaN                  NaN        NaN
# 4                 NaN                    NaN                  NaN        NaN
# ..                ...                    ...                  ...        ...
# 220               NaN                    NaN                  NaN        NaN
# 221               NaN                    NaN                  NaN        NaN
# 222               NaN                    NaN                  NaN        NaN
# 223               NaN                    NaN                  NaN        NaN
# 224               NaN                    NaN                  NaN        NaN
#
#     Tumor Size (cm) protein_change_numbers_only
# 0               NaN                        1728
# 1               NaN                        1823
# 2               NaN                        1559
# 3               NaN                        1788
# 4               NaN                        1121
# ..              ...                         ...
# 220             NaN                          96
# 221             NaN                         644
# 222             NaN                           9
# 223             NaN                         366
# 224             NaN                        1419
#
# [225 rows x 589 columns]

# %%
protein_change['protein_change_numbers_only'].unique()
# Out:
# array(['1728', '1823', '1559', '1788', '1121', '23', '1811', '911',
#        '1495', '101', '1371', '358', '1219', '729', '648', '71', '1835',
#        '111', '1508', '720', '934', '27', '688', '272', '1408', '1329',
#        '903', '1463', '1654', '1667', '202', '709', '1731', '1760', '150',
#        '1494', '1453', '880', '560', '282', '1663', '502', '655', '686',
#        '1253', '1356', '1212', '1849', '1614', '1802', '340', '1759',
#        '936', '139', '1699', '1756', '1346', '61', '1713', '1323', '198',
#        '250', '845', '411', '1154', '667', '360', '1581', '1085', '1344',
#        '951', '1708', '456', '1512', '866', '871', '1590', '197', '1220',
#        '14', '1240', '373', '608', '1395', '1825', '561', '1569', '1066',
#        '496', '364', '81', '864', '1525', '868', '1564', '1027', '96',
#        '644', '9', '366', '1419', '1098', '83', '2', '915', '1578',
#        '1589', '1737', '1692', '1813', '1439', '1836', '1551', '914',
#        '420', '1127', '1074', '372', '216', '495', '153', '1087', '305',
#        '946', '1827', '143', '613', '1266', '391', '1287', '171', '452',
#        '757', '1249', '979', '695', '479', '1484', '650', '248', '1795',
#        '747', '759', '1446', '1151', '585', '732', '580', '547', '761',
#        '1030', '50', '1126', '1238'], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
protein_change.drop(columns= ['Study of Origin'])
# Out:
#                                   Sample ID    Cancer Type  \
# 0                                    MBC_47  Breast Cancer
# 1    MBC-MBCProject_zatdFvhp-Tumor-SM-GQAAR  Breast Cancer
# 2                           TCGA-BH-A0WA-01  Breast Cancer
# 3                           TCGA-AN-A0XU-01  Breast Cancer
# 4                           TCGA-AR-A0U4-01  Breast Cancer
# ..                                      ...            ...
# 220                         TCGA-LL-A5YP-01  Breast Cancer
# 221                         TCGA-AO-A1KR-01  Breast Cancer
# 222                         TCGA-A1-A0SI-01  Breast Cancer
# 223                         TCGA-EW-A2FR-01  Breast Cancer
# 224                         TCGA-PE-A5DE-01  Breast Cancer
#
#                   Cancer Type Detailed protein_change     aminoacid  \
# 0            Invasive Breast Carcinoma     M1728Kfs*3      M1728Kfs
# 1          Breast Invasive Cancer, NOS   X1823_splice  X1823_splice
# 2            Invasive Breast Carcinoma   X1559_splice  X1559_splice
# 3            Invasive Breast Carcinoma         G1788V        G1788V
# 4            Invasive Breast Carcinoma    N1121Kfs*12      N1121Kfs
# ..                                 ...            ...           ...
# 220   Breast Invasive Ductal Carcinoma           D96H          D96H
# 221   Breast Invasive Ductal Carcinoma        C644del       C644del
# 222   Breast Invasive Ductal Carcinoma            E9Q           E9Q
# 223   Breast Invasive Ductal Carcinoma          D366N         D366N
# 224  Breast Invasive Lobular Carcinoma         E1419K        E1419K
#
#     Annotation OncoKb CancerHotspot MutationAssesor Impact  SIFT Impact  \
# 0    Likely Oncogenic            no                    NaN          NaN
# 1    Likely Oncogenic            no                    NaN          NaN
# 2    Likely Oncogenic            no                    NaN          NaN
# 3    Likely Oncogenic            no                 medium  deleterious
# 4    Likely Oncogenic            no                    NaN          NaN
# ..                ...           ...                    ...          ...
# 220           Unknown            no                 medium          NaN
# 221           Unknown            no                    NaN          NaN
# 222           Unknown            no                    low          NaN
# 223           Unknown            no                 medium    tolerated
# 224           Unknown            no                 medium  deleterious
#
#      SIFT Score  ... Tumor Sample Histology  Tumor Tissue Origin T Stage  \
# 0           NaN  ...                    NaN                  NaN     NaN
# 1           NaN  ...                    NaN                  NaN     NaN
# 2           NaN  ...                    NaN                  NaN     NaN
# 3          0.00  ...                    NaN                  NaN     NaN
# 4           NaN  ...                    NaN                  NaN     NaN
# ..          ...  ...                    ...                  ...     ...
# 220         NaN  ...                    NaN                  NaN     NaN
# 221         NaN  ...                    NaN                  NaN     NaN
# 222         NaN  ...                    NaN                  NaN     NaN
# 223        0.18  ...                    NaN                  NaN     NaN
# 224        0.00  ...                    NaN                  NaN     NaN
#
#      Archer Panel Institute Source  Patient Display Name.1  \
# 0             NaN              NaN                     NaN
# 1             NaN              NaN                     NaN
# 2             NaN              NaN                     NaN
# 3             NaN              NaN                     NaN
# 4             NaN              NaN                     NaN
# ..            ...              ...                     ...
# 220           NaN              NaN                     NaN
# 221           NaN              NaN                     NaN
# 222           NaN              NaN                     NaN
# 223           NaN              NaN                     NaN
# 224           NaN              NaN                     NaN
#
#     Sample Display Name Tumor Site Tumor Size (cm)  \
# 0                   NaN        NaN             NaN
# 1                   NaN        NaN             NaN
# 2                   NaN        NaN             NaN
# 3                   NaN        NaN             NaN
# 4                   NaN        NaN             NaN
# ..                  ...        ...             ...
# 220                 NaN        NaN             NaN
# 221                 NaN        NaN             NaN
# 222                 NaN        NaN             NaN
# 223                 NaN        NaN             NaN
# 224                 NaN        NaN             NaN
#
#      protein_change_numbers_only
# 0                           1728
# 1                           1823
# 2                           1559
# 3                           1788
# 4                           1121
# ..                           ...
# 220                           96
# 221                          644
# 222                            9
# 223                          366
# 224                         1419
#
# [225 rows x 588 columns]

# %%
#Selección de columnas
columnas_seleccionadas = [
    "SIFT Score",
    'Polyphen-2 Score']
protein_change_nan = protein_change.dropna(subset=columnas_seleccionadas)

# %%
#Definición de variables
X = protein_change_nan['SIFT Score'].to_frame()
y = protein_change_nan['protein_change_numbers_only']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
logreg = LogisticRegression(max_iter=10_000)

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = logreg.predict(X_test)
y_pred
# Out:
# array(['1344', '1344', '1344', '1344', '1344', '1344', '1344', '1344',
#        '1344', '1344', '1344', '1344', '1344', '1344', '1344', '1344',
#        '1344', '1344', '1344', '1344', '1344', '1344', '1344', '1344',
#        '1344', '1344', '1344', '1344', '1344', '1344', '1344', '1344'],
#       dtype=object)

# %%
logreg.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# K-Means (Algoritmo no supervisado)

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.set_title('Grado de Afectación celular')
ax.set_xlabel('Sift Score')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')  # Ajustar el ángulo de rotación

sns.scatterplot(x=protein_change_nan['SIFT Score'], y=protein_change_nan['Polyphen-2 Score'], ax=ax)
# Out:
# <ipython-input-218-0af8a6a3616c>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')  # Ajustar el ángulo de rotación
# <Axes: title={'center': 'Grado de Afectación celular'}, xlabel='Sift Score', ylabel='Polyphen-2 Score'>

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans(n_clusters=6, max_iter=10_000)

# %%
k_means.fit(protein_change_nan[['SIFT Score', 'Polyphen-2 Score']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(max_iter=10000, n_clusters=6)

# %%
k_means.cluster_centers_
# Out:
# array([[0.01384615, 0.95692308],
#        [0.05409091, 0.09236364],
#        [0.06105263, 0.53942105],
#        [0.49166667, 0.04433333],
#        [0.0335    , 0.777     ],
#        [0.985     , 0.        ]])

# %%
centers = k_means.cluster_centers_
fig = plt.figure()
ax = fig.add_subplot()

ax.set_title('Grado de Afectación celular')
ax.set_xlabel('Sift Score')
ax.set_ylabel('Polyphen-2 Score')

sns.scatterplot(x=protein_change_nan['SIFT Score'], y=protein_change_nan['Polyphen-2 Score'], ax=ax)
sns.scatterplot(x=centers[:,0], y=centers[:,1], ax=ax, s=100, c='orange')
# Out:
# <Axes: title={'center': 'Grado de Afectación celular'}, xlabel='Sift Score', ylabel='Polyphen-2 Score'>

# %%
clasificaciones = k_means.predict(protein_change_nan[['SIFT Score', 'Polyphen-2 Score']])

# %%
centers = k_means.cluster_centers_
fig = plt.figure()
ax = fig.add_subplot()

ax.set_title('Grado de Afectación celular')
ax.set_xlabel('Sift Score')
ax.set_ylabel('Polyphen-2 Score')

sns.scatterplot(x=protein_change_nan['SIFT Score'], y=protein_change_nan['Polyphen-2 Score'], hue=clasificaciones, ax=ax, palette='rainbow')
sns.scatterplot(x=centers[:,0], y=centers[:,1], ax=ax, s=100, c='black')
# Out:
# <Axes: title={'center': 'Grado de Afectación celular'}, xlabel='Sift Score', ylabel='Polyphen-2 Score'>
